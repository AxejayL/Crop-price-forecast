# %% [markdown]
# # 2D Design Template

# %% [markdown]
# # Overview
#
# The purpose of this project is for you to apply what you have learnt in this course. This includes working with data and visualizing it, create model of linear regression or logistic regression, as well as using metrics to measure the accuracy of your model.
#
# Please find the project handout description in the following link:
# - [DDW-MU-Humanities Handout](https://sutdapac-my.sharepoint.com/:w:/g/personal/franklin_anariba_sutd_edu_sg/ESlibHS4e3hDtOyWQ8noqdsBrC8UXO3wwMmTszX6vFIVVg?e=rjIslZ)
# - [DDW-MU-SocialStudies Handout](https://sutdapac-my.sharepoint.com/:w:/g/personal/franklin_anariba_sutd_edu_sg/EQ8CAm4PPupOlXqv9zTNkQYBpD_yGdwMWytBYpJTi9dzew?e=beEbac)

# %% [markdown]
# ## Deliverables
#
# You need to submit this Jupyter notebook together with the dataset into Vocareum. Use the template in this notebook to work on this project.

# %% [markdown]
# ## Students Submission
#
# Student's Name:
# - Koh Jin Rui Vinny
# - Teh Hui Yi
# -Loy Xing Jun
# -Gareth Tan
# -Bryan

# %% [markdown]
# ### Overview About the Problem
#
# Describe here the problem you are trying to solve.

# %% [raw]
# # RELEVANCE AND DESIGN OPPORTUNITY

# %% [raw]
# # PROBLEM STATEMENT
# How might we predict the prices of each of the 5 identified crops(Broccoli,Potato,Corn,Cucumber,Carrot) in US based on factors such as the amount of each type of chemical (pesticide,herbicide,fungicide) used on each type of crop and price of each type of chemical so as to predict the total cost of consumption of these 5 crops

# %% [markdown]
# ### Dataset
#
# Describe here your data set. Put the link to the sources of your dataset. Describe your data and what are the columns.
#
# Put some Python codes here to describe and visualize your data.

# %% [raw]
# # DATASET DESCRIPTION
# The current dataset involves (for each crop):
#
# 1 dependent variable:
# -price of crop (USD/tonne)
#
# 6 independent variables:
# -amount of pesticide used on this crop type across the whole of US (lb)
# -amount of herbicide used on this crop type across the whole of US (lb)
# -amount of fungicide used on this crop type across the whole of US (lb)
# -price of pesticide (USD/ gallon)
# -price of herbicide (USD/ gallon)
# -price of fungicide (USD/ gallon)
#
# All data are across time intervals within 1990-2021

# %% [raw]
# # LINK
# all above data is retrieved from
# https://quickstats.nass.usda.gov/
#
# data used in improvements retrieved from
# https://www.statista.com/statistics/381907/per-capita-consumption-of-fresh-potatoes-in-the-us/
# https://www.statista.com/statistics/257338/per-capita-consumption-of-fresh-broccoli-in-the-us/
# https://www.statista.com/statistics/257333/per-capita-consumption-of-fresh-carrots-in-the-us/
# https://www.statista.com/statistics/257324/per-capita-consumption-of-fresh-cucumbers-in-the-us/
# https://www.statista.com/statistics/184202/per-capita-consumption-of-corn-products-in-the-us-since-2000/
# https://population.un.org/wpp/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csv_files=[
    "Broccoli Fungicide.csv",
    "Broccoli Herbicide.csv",
    "Broccoli Pesticide.csv",
    "Broccoli Price.csv",
    "Carrot Fungicide.csv",
    "Carrot Herbicide.csv",
    "Carrot Pesticide.csv",
    "Carrot Price.csv",
    "Corn Fungicide.csv",
    "Corn Herbicide.csv",
    "Corn Pesticide.csv",
    "Corn Price.csv",
    "Cucumber Fungicide.csv",
    "Cucumber Herbicide.csv",
    "Cucumber Pesticide.csv",
    "Cucumber Price.csv",
    "Potato Fungicide.csv",
    "Potato Herbicide.csv",
    "Potato Pesticide.csv",
    "Potato Price.csv",
    "Fungicide Price.csv",
    "Herbicide Price.csv",
    "Pesticide Price.csv"
]
for file in csv_files:
    df=pd.read_csv(file)
    print(f"\n \n ----------------------------------{file}--------------------------------------------------------------")
    display(df)
# Out:
#
#  ----------------------------------Broccoli Fungicide.csv--------------------------------------------------------------
#    Program    Year Period  Week Ending             Geo Level  State  \
# 0   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 1   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 2   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 3      NaN     NaN    NaN          NaN                   NaN    NaN
# 4   SURVEY  1994.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 5   SURVEY  1998.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 6   SURVEY  2000.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 7   SURVEY  2006.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 8   SURVEY  2010.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 9   SURVEY  2014.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 10  SURVEY  2016.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 11  SURVEY  2018.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 12  SURVEY  2020.0   YEAR          NaN  REGION : MULTI-STATE    NaN
#
#     State ANSI  Ag District  Ag District Code  County  ...  Zip Code  \
# 0          NaN          NaN               NaN     NaN  ...       NaN
# 1          NaN          NaN               NaN     NaN  ...       NaN
# 2          NaN          NaN               NaN     NaN  ...       NaN
# 3          NaN          NaN               NaN     NaN  ...       NaN
# 4          NaN          NaN               NaN     NaN  ...       NaN
# 5          NaN          NaN               NaN     NaN  ...       NaN
# 6          NaN          NaN               NaN     NaN  ...       NaN
# 7          NaN          NaN               NaN     NaN  ...       NaN
# 8          NaN          NaN               NaN     NaN  ...       NaN
# 9          NaN          NaN               NaN     NaN  ...       NaN
# 10         NaN          NaN               NaN     NaN  ...       NaN
# 11         NaN          NaN               NaN     NaN  ...       NaN
# 12         NaN          NaN               NaN     NaN  ...       NaN
#
#             Region watershed_code  Watershed  Commodity  \
# 0   PROGRAM STATES            0.0        NaN   BROCCOLI
# 1   PROGRAM STATES            0.0        NaN   BROCCOLI
# 2   PROGRAM STATES            0.0        NaN   BROCCOLI
# 3              NaN            NaN        NaN        NaN
# 4   PROGRAM STATES            0.0        NaN   BROCCOLI
# 5   PROGRAM STATES            0.0        NaN   BROCCOLI
# 6   PROGRAM STATES            0.0        NaN   BROCCOLI
# 7   PROGRAM STATES            0.0        NaN   BROCCOLI
# 8   PROGRAM STATES            0.0        NaN   BROCCOLI
# 9   PROGRAM STATES            0.0        NaN   BROCCOLI
# 10  PROGRAM STATES            0.0        NaN   BROCCOLI
# 11  PROGRAM STATES            0.0        NaN   BROCCOLI
# 12  PROGRAM STATES            0.0        NaN   BROCCOLI
#
#                                   Data Item               Domain  \
# 0   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, FUNGICIDE
# 1   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, FUNGICIDE
# 2   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, FUNGICIDE
# 3                                       NaN                  NaN
# 4   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, FUNGICIDE
# 5   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, FUNGICIDE
# 6   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, FUNGICIDE
# 7   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, FUNGICIDE
# 8   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, FUNGICIDE
# 9   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, FUNGICIDE
# 10  BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, FUNGICIDE
# 11  BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, FUNGICIDE
# 12  BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, FUNGICIDE
#
#                                     Domain Category   Value CV (%)
# 0     CHEMICAL, FUNGICIDE: (CHLOROTHALONIL = 81901)  20,400    NaN
# 1   CHEMICAL, FUNGICIDE: (COPPER HYDROXIDE = 23401)   2,800    NaN
# 2         CHEMICAL, FUNGICIDE: (METALAXYL = 113501)   5,100    NaN
# 3                                        1992 Total  28,300    NaN
# 4                      CHEMICAL, FUNGICIDE: (TOTAL)  47,500    NaN
# 5                      CHEMICAL, FUNGICIDE: (TOTAL)  36,700    NaN
# 6                      CHEMICAL, FUNGICIDE: (TOTAL)  25,900    NaN
# 7                      CHEMICAL, FUNGICIDE: (TOTAL)  15,300    NaN
# 8                      CHEMICAL, FUNGICIDE: (TOTAL)  40,700    NaN
# 9                      CHEMICAL, FUNGICIDE: (TOTAL)  48,500    NaN
# 10                     CHEMICAL, FUNGICIDE: (TOTAL)  37,400    NaN
# 11                     CHEMICAL, FUNGICIDE: (TOTAL)  89,100    NaN
# 12                     CHEMICAL, FUNGICIDE: (TOTAL)  59,900    NaN
#
# [13 rows x 21 columns]
#
#  ----------------------------------Broccoli Herbicide.csv--------------------------------------------------------------
#    Program    Year Period  Week Ending             Geo Level  State  \
# 0   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 1   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 2   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 3   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 4   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 5      NaN     NaN    NaN          NaN                   NaN    NaN
# 6   SURVEY  1994.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 7   SURVEY  1998.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 8   SURVEY  2000.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 9   SURVEY  2006.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 10  SURVEY  2010.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 11  SURVEY  2014.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 12  SURVEY  2016.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 13  SURVEY  2018.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 14  SURVEY  2020.0   YEAR          NaN  REGION : MULTI-STATE    NaN
#
#     State ANSI  Ag District  Ag District Code  County  ...  Zip Code  \
# 0          NaN          NaN               NaN     NaN  ...       NaN
# 1          NaN          NaN               NaN     NaN  ...       NaN
# 2          NaN          NaN               NaN     NaN  ...       NaN
# 3          NaN          NaN               NaN     NaN  ...       NaN
# 4          NaN          NaN               NaN     NaN  ...       NaN
# 5          NaN          NaN               NaN     NaN  ...       NaN
# 6          NaN          NaN               NaN     NaN  ...       NaN
# 7          NaN          NaN               NaN     NaN  ...       NaN
# 8          NaN          NaN               NaN     NaN  ...       NaN
# 9          NaN          NaN               NaN     NaN  ...       NaN
# 10         NaN          NaN               NaN     NaN  ...       NaN
# 11         NaN          NaN               NaN     NaN  ...       NaN
# 12         NaN          NaN               NaN     NaN  ...       NaN
# 13         NaN          NaN               NaN     NaN  ...       NaN
# 14         NaN          NaN               NaN     NaN  ...       NaN
#
#             Region watershed_code  Watershed  Commodity  \
# 0   PROGRAM STATES            0.0        NaN   BROCCOLI
# 1   PROGRAM STATES            0.0        NaN   BROCCOLI
# 2   PROGRAM STATES            0.0        NaN   BROCCOLI
# 3   PROGRAM STATES            0.0        NaN   BROCCOLI
# 4   PROGRAM STATES            0.0        NaN   BROCCOLI
# 5              NaN            NaN        NaN        NaN
# 6   PROGRAM STATES            0.0        NaN   BROCCOLI
# 7   PROGRAM STATES            0.0        NaN   BROCCOLI
# 8   PROGRAM STATES            0.0        NaN   BROCCOLI
# 9   PROGRAM STATES            0.0        NaN   BROCCOLI
# 10  PROGRAM STATES            0.0        NaN   BROCCOLI
# 11  PROGRAM STATES            0.0        NaN   BROCCOLI
# 12  PROGRAM STATES            0.0        NaN   BROCCOLI
# 13  PROGRAM STATES            0.0        NaN   BROCCOLI
# 14  PROGRAM STATES            0.0        NaN   BROCCOLI
#
#                                   Data Item               Domain  \
# 0   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, HERBICIDE
# 1   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, HERBICIDE
# 2   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, HERBICIDE
# 3   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, HERBICIDE
# 4   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, HERBICIDE
# 5                                       NaN                  NaN
# 6   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, HERBICIDE
# 7   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, HERBICIDE
# 8   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, HERBICIDE
# 9   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, HERBICIDE
# 10  BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, HERBICIDE
# 11  BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, HERBICIDE
# 12  BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, HERBICIDE
# 13  BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, HERBICIDE
# 14  BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, HERBICIDE
#
#                                 Domain Category    Value CV (%)
# 0           CHEMICAL, HERBICIDE: (DCPA = 78701)  206,100    NaN
# 1   CHEMICAL, HERBICIDE: (NAPROPAMIDE = 103001)    1,400    NaN
# 2   CHEMICAL, HERBICIDE: (OXYFLUORFEN = 111601)      100    NaN
# 3    CHEMICAL, HERBICIDE: (SETHOXYDIM = 121001)      100    NaN
# 4    CHEMICAL, HERBICIDE: (TRIFLURALIN = 36101)    6,300    NaN
# 5                                    1992 Total  214,000    NaN
# 6                  CHEMICAL, HERBICIDE: (TOTAL)  242,100    NaN
# 7                  CHEMICAL, HERBICIDE: (TOTAL)  177,400    NaN
# 8                  CHEMICAL, HERBICIDE: (TOTAL)  234,300    NaN
# 9                  CHEMICAL, HERBICIDE: (TOTAL)  218,900    NaN
# 10                 CHEMICAL, HERBICIDE: (TOTAL)  133,000    NaN
# 11                 CHEMICAL, HERBICIDE: (TOTAL)  228,400    NaN
# 12                 CHEMICAL, HERBICIDE: (TOTAL)  135,100    NaN
# 13                 CHEMICAL, HERBICIDE: (TOTAL)  110,300    NaN
# 14                 CHEMICAL, HERBICIDE: (TOTAL)   83,400    NaN
#
# [15 rows x 21 columns]
#
#  ----------------------------------Broccoli Pesticide.csv--------------------------------------------------------------
#    Program    Year Period  Week Ending             Geo Level  State  \
# 0   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 1   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 2   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 3   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 4   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 5   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 6   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 7   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 8   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 9   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 10  SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 11  SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 12  SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 13  SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 14  SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 15     NaN     NaN    NaN          NaN                   NaN    NaN
# 16  SURVEY  1994.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 17  SURVEY  1998.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 18  SURVEY  2000.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 19  SURVEY  2006.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 20  SURVEY  2010.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 21  SURVEY  2014.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 22  SURVEY  2016.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 23  SURVEY  2018.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 24  SURVEY  2020.0   YEAR          NaN  REGION : MULTI-STATE    NaN
#
#     State ANSI  Ag District  Ag District Code  County  ...  Zip Code  \
# 0          NaN          NaN               NaN     NaN  ...       NaN
# 1          NaN          NaN               NaN     NaN  ...       NaN
# 2          NaN          NaN               NaN     NaN  ...       NaN
# 3          NaN          NaN               NaN     NaN  ...       NaN
# 4          NaN          NaN               NaN     NaN  ...       NaN
# 5          NaN          NaN               NaN     NaN  ...       NaN
# 6          NaN          NaN               NaN     NaN  ...       NaN
# 7          NaN          NaN               NaN     NaN  ...       NaN
# 8          NaN          NaN               NaN     NaN  ...       NaN
# 9          NaN          NaN               NaN     NaN  ...       NaN
# 10         NaN          NaN               NaN     NaN  ...       NaN
# 11         NaN          NaN               NaN     NaN  ...       NaN
# 12         NaN          NaN               NaN     NaN  ...       NaN
# 13         NaN          NaN               NaN     NaN  ...       NaN
# 14         NaN          NaN               NaN     NaN  ...       NaN
# 15         NaN          NaN               NaN     NaN  ...       NaN
# 16         NaN          NaN               NaN     NaN  ...       NaN
# 17         NaN          NaN               NaN     NaN  ...       NaN
# 18         NaN          NaN               NaN     NaN  ...       NaN
# 19         NaN          NaN               NaN     NaN  ...       NaN
# 20         NaN          NaN               NaN     NaN  ...       NaN
# 21         NaN          NaN               NaN     NaN  ...       NaN
# 22         NaN          NaN               NaN     NaN  ...       NaN
# 23         NaN          NaN               NaN     NaN  ...       NaN
# 24         NaN          NaN               NaN     NaN  ...       NaN
#
#             Region watershed_code  Watershed  Commodity  \
# 0   PROGRAM STATES            0.0        NaN   BROCCOLI
# 1   PROGRAM STATES            0.0        NaN   BROCCOLI
# 2   PROGRAM STATES            0.0        NaN   BROCCOLI
# 3   PROGRAM STATES            0.0        NaN   BROCCOLI
# 4   PROGRAM STATES            0.0        NaN   BROCCOLI
# 5   PROGRAM STATES            0.0        NaN   BROCCOLI
# 6   PROGRAM STATES            0.0        NaN   BROCCOLI
# 7   PROGRAM STATES            0.0        NaN   BROCCOLI
# 8   PROGRAM STATES            0.0        NaN   BROCCOLI
# 9   PROGRAM STATES            0.0        NaN   BROCCOLI
# 10  PROGRAM STATES            0.0        NaN   BROCCOLI
# 11  PROGRAM STATES            0.0        NaN   BROCCOLI
# 12  PROGRAM STATES            0.0        NaN   BROCCOLI
# 13  PROGRAM STATES            0.0        NaN   BROCCOLI
# 14  PROGRAM STATES            0.0        NaN   BROCCOLI
# 15             NaN            NaN        NaN        NaN
# 16  PROGRAM STATES            0.0        NaN   BROCCOLI
# 17  PROGRAM STATES            0.0        NaN   BROCCOLI
# 18  PROGRAM STATES            0.0        NaN   BROCCOLI
# 19  PROGRAM STATES            0.0        NaN   BROCCOLI
# 20  PROGRAM STATES            0.0        NaN   BROCCOLI
# 21  PROGRAM STATES            0.0        NaN   BROCCOLI
# 22  PROGRAM STATES            0.0        NaN   BROCCOLI
# 23  PROGRAM STATES            0.0        NaN   BROCCOLI
# 24  PROGRAM STATES            0.0        NaN   BROCCOLI
#
#                                   Data Item                 Domain  \
# 0   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 1   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 2   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 3   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 4   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 5   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 6   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 7   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 8   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 9   BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 10  BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 11  BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 12  BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 13  BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 14  BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 15                                      NaN                    NaN
# 16  BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 17  BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 18  BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 19  BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 20  BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 21  BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 22  BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 23  BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 24  BROCCOLI - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
#
#                                       Domain Category    Value CV (%)
# 0           CHEMICAL, INSECTICIDE: (CARBARYL = 56801)    4,100    NaN
# 1       CHEMICAL, INSECTICIDE: (CHLORPYRIFOS = 59101)   63,300    NaN
# 2           CHEMICAL, INSECTICIDE: (DIAZINON = 57801)    9,500    NaN
# 3         CHEMICAL, INSECTICIDE: (DIMETHOATE = 35001)   18,100    NaN
# 4         CHEMICAL, INSECTICIDE: (DISULFOTON = 32501)   14,700    NaN
# 5         CHEMICAL, INSECTICIDE: (ENDOSULFAN = 79401)   15,900    NaN
# 6     CHEMICAL, INSECTICIDE: (ESFENVALERATE = 109303)    3,100    NaN
# 7        CHEMICAL, INSECTICIDE: (FENAMIPHOS = 100601)   31,800    NaN
# 8            CHEMICAL, INSECTICIDE: (FONOFOS = 41701)    4,200    NaN
# 9     CHEMICAL, INSECTICIDE: (METHAMIDOPHOS = 101201)   10,700    NaN
# 10          CHEMICAL, INSECTICIDE: (METHOMYL = 90301)   17,400    NaN
# 11         CHEMICAL, INSECTICIDE: (MEVINPHOS = 15801)   24,400    NaN
# 12             CHEMICAL, INSECTICIDE: (NALED = 34401)    3,900    NaN
# 13  CHEMICAL, INSECTICIDE: (OXYDEMETON-METHYL = 58...   37,800    NaN
# 14       CHEMICAL, INSECTICIDE: (PERMETHRIN = 109701)    4,200    NaN
# 15                                         Total 1992  263,100    NaN
# 16                     CHEMICAL, INSECTICIDE: (TOTAL)  286,900    NaN
# 17                     CHEMICAL, INSECTICIDE: (TOTAL)  176,800    NaN
# 18                     CHEMICAL, INSECTICIDE: (TOTAL)  270,100    NaN
# 19                     CHEMICAL, INSECTICIDE: (TOTAL)  180,500    NaN
# 20                     CHEMICAL, INSECTICIDE: (TOTAL)  121,300    NaN
# 21                     CHEMICAL, INSECTICIDE: (TOTAL)  120,500    NaN
# 22                     CHEMICAL, INSECTICIDE: (TOTAL)   69,000    NaN
# 23                     CHEMICAL, INSECTICIDE: (TOTAL)  101,300    NaN
# 24                     CHEMICAL, INSECTICIDE: (TOTAL)   50,800    NaN
#
# [25 rows x 21 columns]
#
#  ----------------------------------Broccoli Price.csv--------------------------------------------------------------
#    Program  Year          Period  Week Ending Geo Level     State  State ANSI  \
# 0   SURVEY  1996  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 1   SURVEY  1997  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 2   SURVEY  1998            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 3   SURVEY  1998  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 4   SURVEY  1999            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 5   SURVEY  1999  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 6   SURVEY  2000            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 7   SURVEY  2001            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 8   SURVEY  2002            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 9   SURVEY  2003            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 10  SURVEY  2004            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 11  SURVEY  2005            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 12  SURVEY  2006            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 13  SURVEY  2006  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 14  SURVEY  2007            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 15  SURVEY  2007  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 16  SURVEY  2008            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 17  SURVEY  2008  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 18  SURVEY  2009            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 19  SURVEY  2009  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 20  SURVEY  2010            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 21  SURVEY  2010  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 22  SURVEY  2011            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 23  SURVEY  2011  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 24  SURVEY  2012  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 25  SURVEY  2013  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 26  SURVEY  2014  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 27  SURVEY  2015  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 28  SURVEY  2016  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 29  SURVEY  2017  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 30  SURVEY  2018  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 31  SURVEY  2019  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 32  SURVEY  2020  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 33  SURVEY  2021  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
#
#     Ag District  Ag District Code  County  ...  Zip Code  Region  \
# 0           NaN               NaN     NaN  ...       NaN     NaN
# 1           NaN               NaN     NaN  ...       NaN     NaN
# 2           NaN               NaN     NaN  ...       NaN     NaN
# 3           NaN               NaN     NaN  ...       NaN     NaN
# 4           NaN               NaN     NaN  ...       NaN     NaN
# 5           NaN               NaN     NaN  ...       NaN     NaN
# 6           NaN               NaN     NaN  ...       NaN     NaN
# 7           NaN               NaN     NaN  ...       NaN     NaN
# 8           NaN               NaN     NaN  ...       NaN     NaN
# 9           NaN               NaN     NaN  ...       NaN     NaN
# 10          NaN               NaN     NaN  ...       NaN     NaN
# 11          NaN               NaN     NaN  ...       NaN     NaN
# 12          NaN               NaN     NaN  ...       NaN     NaN
# 13          NaN               NaN     NaN  ...       NaN     NaN
# 14          NaN               NaN     NaN  ...       NaN     NaN
# 15          NaN               NaN     NaN  ...       NaN     NaN
# 16          NaN               NaN     NaN  ...       NaN     NaN
# 17          NaN               NaN     NaN  ...       NaN     NaN
# 18          NaN               NaN     NaN  ...       NaN     NaN
# 19          NaN               NaN     NaN  ...       NaN     NaN
# 20          NaN               NaN     NaN  ...       NaN     NaN
# 21          NaN               NaN     NaN  ...       NaN     NaN
# 22          NaN               NaN     NaN  ...       NaN     NaN
# 23          NaN               NaN     NaN  ...       NaN     NaN
# 24          NaN               NaN     NaN  ...       NaN     NaN
# 25          NaN               NaN     NaN  ...       NaN     NaN
# 26          NaN               NaN     NaN  ...       NaN     NaN
# 27          NaN               NaN     NaN  ...       NaN     NaN
# 28          NaN               NaN     NaN  ...       NaN     NaN
# 29          NaN               NaN     NaN  ...       NaN     NaN
# 30          NaN               NaN     NaN  ...       NaN     NaN
# 31          NaN               NaN     NaN  ...       NaN     NaN
# 32          NaN               NaN     NaN  ...       NaN     NaN
# 33          NaN               NaN     NaN  ...       NaN     NaN
#
#     watershed_code  Watershed  Commodity  \
# 0                0        NaN   BROCCOLI
# 1                0        NaN   BROCCOLI
# 2                0        NaN   BROCCOLI
# 3                0        NaN   BROCCOLI
# 4                0        NaN   BROCCOLI
# 5                0        NaN   BROCCOLI
# 6                0        NaN   BROCCOLI
# 7                0        NaN   BROCCOLI
# 8                0        NaN   BROCCOLI
# 9                0        NaN   BROCCOLI
# 10               0        NaN   BROCCOLI
# 11               0        NaN   BROCCOLI
# 12               0        NaN   BROCCOLI
# 13               0        NaN   BROCCOLI
# 14               0        NaN   BROCCOLI
# 15               0        NaN   BROCCOLI
# 16               0        NaN   BROCCOLI
# 17               0        NaN   BROCCOLI
# 18               0        NaN   BROCCOLI
# 19               0        NaN   BROCCOLI
# 20               0        NaN   BROCCOLI
# 21               0        NaN   BROCCOLI
# 22               0        NaN   BROCCOLI
# 23               0        NaN   BROCCOLI
# 24               0        NaN   BROCCOLI
# 25               0        NaN   BROCCOLI
# 26               0        NaN   BROCCOLI
# 27               0        NaN   BROCCOLI
# 28               0        NaN   BROCCOLI
# 29               0        NaN   BROCCOLI
# 30               0        NaN   BROCCOLI
# 31               0        NaN   BROCCOLI
# 32               0        NaN   BROCCOLI
# 33               0        NaN   BROCCOLI
#
#                                          Data Item Domain Domain Category  \
# 0   BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 1   BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 2   BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 3   BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 4   BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 5   BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 6   BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 7   BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 8   BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 9   BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 10  BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 11  BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 12  BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 13  BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 14  BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 15  BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 16  BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 17  BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 18  BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 19  BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 20  BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 21  BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 22  BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 23  BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 24  BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 25  BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 26  BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 27  BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 28  BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 29  BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 30  BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 31  BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 32  BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 33  BROCCOLI - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
#
#    Value  CV (%)
# 0   27.1     NaN
# 1   28.5     NaN
# 2   29.5     NaN
# 3   30.2     NaN
# 4   23.9     NaN
# 5   24.1     NaN
# 6   30.5     NaN
# 7   25.9     NaN
# 8   30.9     NaN
# 9   31.6     NaN
# 10  32.1     NaN
# 11  28.5     NaN
# 12  33.3     NaN
# 13  33.3     NaN
# 14  36.2     NaN
# 15  36.2     NaN
# 16  35.9     NaN
# 17  35.9     NaN
# 18  39.9     NaN
# 19  39.9     NaN
# 20  35.6     NaN
# 21  37.7     NaN
# 22  35.1     NaN
# 23  35.2     NaN
# 24  33.6     NaN
# 25  42.8     NaN
# 26  40.0     NaN
# 27  48.4     NaN
# 28  37.7     NaN
# 29  45.4     NaN
# 30  42.8     NaN
# 31  51.3     NaN
# 32  55.5     NaN
# 33  52.2     NaN
#
# [34 rows x 21 columns]
#
#  ----------------------------------Carrot Fungicide.csv--------------------------------------------------------------
#    Program    Year Period  Week Ending             Geo Level  State  \
# 0   SURVEY  2020.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 1   SURVEY  2018.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 2   SURVEY  1996.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 3   SURVEY  1994.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 4   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 5   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 6   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 7   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 8   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 9   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 10     NaN     NaN    NaN          NaN                   NaN    NaN
#
#     State ANSI  Ag District  Ag District Code  County  ...  Zip Code  \
# 0          NaN          NaN               NaN     NaN  ...       NaN
# 1          NaN          NaN               NaN     NaN  ...       NaN
# 2          NaN          NaN               NaN     NaN  ...       NaN
# 3          NaN          NaN               NaN     NaN  ...       NaN
# 4          NaN          NaN               NaN     NaN  ...       NaN
# 5          NaN          NaN               NaN     NaN  ...       NaN
# 6          NaN          NaN               NaN     NaN  ...       NaN
# 7          NaN          NaN               NaN     NaN  ...       NaN
# 8          NaN          NaN               NaN     NaN  ...       NaN
# 9          NaN          NaN               NaN     NaN  ...       NaN
# 10         NaN          NaN               NaN     NaN  ...       NaN
#
#             Region watershed_code  Watershed  Commodity  \
# 0   PROGRAM STATES            0.0        NaN    CARROTS
# 1   PROGRAM STATES            0.0        NaN    CARROTS
# 2   PROGRAM STATES            0.0        NaN    CARROTS
# 3   PROGRAM STATES            0.0        NaN    CARROTS
# 4   PROGRAM STATES            0.0        NaN    CARROTS
# 5   PROGRAM STATES            0.0        NaN    CARROTS
# 6   PROGRAM STATES            0.0        NaN    CARROTS
# 7   PROGRAM STATES            0.0        NaN    CARROTS
# 8   PROGRAM STATES            0.0        NaN    CARROTS
# 9   PROGRAM STATES            0.0        NaN    CARROTS
# 10             NaN            NaN        NaN        NaN
#
#                                  Data Item               Domain  \
# 0   CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, FUNGICIDE
# 1   CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, FUNGICIDE
# 2   CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, FUNGICIDE
# 3   CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, FUNGICIDE
# 4   CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, FUNGICIDE
# 5   CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, FUNGICIDE
# 6   CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, FUNGICIDE
# 7   CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, FUNGICIDE
# 8   CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, FUNGICIDE
# 9   CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, FUNGICIDE
# 10                                     NaN                  NaN
#
#                                       Domain Category    Value CV (%)
# 0                        CHEMICAL, FUNGICIDE: (TOTAL)  893,200    NaN
# 1                        CHEMICAL, FUNGICIDE: (TOTAL)  671,600    NaN
# 2                        CHEMICAL, FUNGICIDE: (TOTAL)  469,100    NaN
# 3                        CHEMICAL, FUNGICIDE: (TOTAL)  483,400    NaN
# 4       CHEMICAL, FUNGICIDE: (CHLOROTHALONIL = 81901)  115,900    NaN
# 5     CHEMICAL, FUNGICIDE: (COPPER HYDROXIDE = 23401)   28,100    NaN
# 6           CHEMICAL, FUNGICIDE: (IPRODIONE = 109801)   21,600    NaN
# 7           CHEMICAL, FUNGICIDE: (METALAXYL = 113501)    5,200    NaN
# 8               CHEMICAL, FUNGICIDE: (SULFUR = 77501)  510,500    NaN
# 9   CHEMICAL, FUNGICIDE: (TRIPHENYLTIN HYDROX. = 8...    5,700    NaN
# 10                                         1992 Total  687,000    NaN
#
# [11 rows x 21 columns]
#
#  ----------------------------------Carrot Herbicide.csv--------------------------------------------------------------
#   Program    Year Period  Week Ending             Geo Level  State  \
# 0  SURVEY  2020.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 1  SURVEY  2018.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 2  SURVEY  1996.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 3  SURVEY  1994.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 4  SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 5  SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 6  SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 7  SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 8     NaN     NaN    NaN          NaN                   NaN    NaN
#
#    State ANSI  Ag District  Ag District Code  County  ...  Zip Code  \
# 0         NaN          NaN               NaN     NaN  ...       NaN
# 1         NaN          NaN               NaN     NaN  ...       NaN
# 2         NaN          NaN               NaN     NaN  ...       NaN
# 3         NaN          NaN               NaN     NaN  ...       NaN
# 4         NaN          NaN               NaN     NaN  ...       NaN
# 5         NaN          NaN               NaN     NaN  ...       NaN
# 6         NaN          NaN               NaN     NaN  ...       NaN
# 7         NaN          NaN               NaN     NaN  ...       NaN
# 8         NaN          NaN               NaN     NaN  ...       NaN
#
#            Region watershed_code  Watershed  Commodity  \
# 0  PROGRAM STATES            0.0        NaN    CARROTS
# 1  PROGRAM STATES            0.0        NaN    CARROTS
# 2  PROGRAM STATES            0.0        NaN    CARROTS
# 3  PROGRAM STATES            0.0        NaN    CARROTS
# 4  PROGRAM STATES            0.0        NaN    CARROTS
# 5  PROGRAM STATES            0.0        NaN    CARROTS
# 6  PROGRAM STATES            0.0        NaN    CARROTS
# 7  PROGRAM STATES            0.0        NaN    CARROTS
# 8             NaN            NaN        NaN        NaN
#
#                                 Data Item               Domain  \
# 0  CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, HERBICIDE
# 1  CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, HERBICIDE
# 2  CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, HERBICIDE
# 3  CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, HERBICIDE
# 4  CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, HERBICIDE
# 5  CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, HERBICIDE
# 6  CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, HERBICIDE
# 7  CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, HERBICIDE
# 8                                     NaN                  NaN
#
#                                      Domain Category    Value CV (%)
# 0                       CHEMICAL, HERBICIDE: (TOTAL)  116,000    NaN
# 1                       CHEMICAL, HERBICIDE: (TOTAL)   57,300    NaN
# 2                       CHEMICAL, HERBICIDE: (TOTAL)  153,200    NaN
# 3                       CHEMICAL, HERBICIDE: (TOTAL)  117,000    NaN
# 4  CHEMICAL, HERBICIDE: (FLUAZIFOP-P-BUTYL = 122809)    3,700    NaN
# 5             CHEMICAL, HERBICIDE: (LINURON = 35506)   67,100    NaN
# 6         CHEMICAL, HERBICIDE: (METRIBUZIN = 101101)      500    NaN
# 7         CHEMICAL, HERBICIDE: (TRIFLURALIN = 36101)   17,800    NaN
# 8                                         1992 Total   89,100    NaN
#
# [9 rows x 21 columns]
#
#  ----------------------------------Carrot Pesticide.csv--------------------------------------------------------------
#    Program    Year Period  Week Ending             Geo Level  State  \
# 0   SURVEY  2020.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 1   SURVEY  2018.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 2   SURVEY  1996.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 3   SURVEY  1994.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 4   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 5   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 6   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 7   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 8   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 9   SURVEY  1992.0   YEAR          NaN  REGION : MULTI-STATE    NaN
# 10     NaN     NaN    NaN          NaN                   NaN    NaN
#
#     State ANSI  Ag District  Ag District Code  County  ...  Zip Code  \
# 0          NaN          NaN               NaN     NaN  ...       NaN
# 1          NaN          NaN               NaN     NaN  ...       NaN
# 2          NaN          NaN               NaN     NaN  ...       NaN
# 3          NaN          NaN               NaN     NaN  ...       NaN
# 4          NaN          NaN               NaN     NaN  ...       NaN
# 5          NaN          NaN               NaN     NaN  ...       NaN
# 6          NaN          NaN               NaN     NaN  ...       NaN
# 7          NaN          NaN               NaN     NaN  ...       NaN
# 8          NaN          NaN               NaN     NaN  ...       NaN
# 9          NaN          NaN               NaN     NaN  ...       NaN
# 10         NaN          NaN               NaN     NaN  ...       NaN
#
#             Region watershed_code  Watershed  Commodity  \
# 0   PROGRAM STATES            0.0        NaN    CARROTS
# 1   PROGRAM STATES            0.0        NaN    CARROTS
# 2   PROGRAM STATES            0.0        NaN    CARROTS
# 3   PROGRAM STATES            0.0        NaN    CARROTS
# 4   PROGRAM STATES            0.0        NaN    CARROTS
# 5   PROGRAM STATES            0.0        NaN    CARROTS
# 6   PROGRAM STATES            0.0        NaN    CARROTS
# 7   PROGRAM STATES            0.0        NaN    CARROTS
# 8   PROGRAM STATES            0.0        NaN    CARROTS
# 9   PROGRAM STATES            0.0        NaN    CARROTS
# 10             NaN            NaN        NaN        NaN
#
#                                  Data Item                 Domain  \
# 0   CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 1   CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 2   CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 3   CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 4   CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 5   CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 6   CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 7   CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 8   CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 9   CARROTS - APPLICATIONS, MEASURED IN LB  CHEMICAL, INSECTICIDE
# 10                                     NaN                    NaN
#
#                                     Domain Category   Value CV (%)
# 0                    CHEMICAL, INSECTICIDE: (TOTAL)   4,700    NaN
# 1                    CHEMICAL, INSECTICIDE: (TOTAL)   4,500    NaN
# 2                    CHEMICAL, INSECTICIDE: (TOTAL)  55,900    NaN
# 3                    CHEMICAL, INSECTICIDE: (TOTAL)  57,700    NaN
# 4         CHEMICAL, INSECTICIDE: (CARBARYL = 56801)   7,900    NaN
# 5         CHEMICAL, INSECTICIDE: (DIAZINON = 57801)  23,300    NaN
# 6   CHEMICAL, INSECTICIDE: (ESFENVALERATE = 109303)   1,500    NaN
# 7         CHEMICAL, INSECTICIDE: (METHOMYL = 90301)   6,200    NaN
# 8        CHEMICAL, INSECTICIDE: (MEVINPHOS = 15801)     900    NaN
# 9          CHEMICAL, INSECTICIDE: (OXAMYL = 103801)   2,200    NaN
# 10                                       1992 Total  42,000    NaN
#
# [11 rows x 21 columns]
#
#  ----------------------------------Carrot Price.csv--------------------------------------------------------------
#    Program  Year          Period  Week Ending Geo Level     State  State ANSI  \
# 0   SURVEY  1998            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 1   SURVEY  1999            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 2   SURVEY  2000            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 3   SURVEY  2001            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 4   SURVEY  2002            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 5   SURVEY  2003            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 6   SURVEY  2004            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 7   SURVEY  2005            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 8   SURVEY  2006            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 9   SURVEY  2007            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 10  SURVEY  2008            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 11  SURVEY  2009            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 12  SURVEY  2010            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 13  SURVEY  2011            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 14  SURVEY  2016  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 15  SURVEY  2017  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 16  SURVEY  2018  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 17  SURVEY  2019  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 18  SURVEY  2020  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 19  SURVEY  2021  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
#
#     Ag District  Ag District Code  County  ...  Zip Code  Region  \
# 0           NaN               NaN     NaN  ...       NaN     NaN
# 1           NaN               NaN     NaN  ...       NaN     NaN
# 2           NaN               NaN     NaN  ...       NaN     NaN
# 3           NaN               NaN     NaN  ...       NaN     NaN
# 4           NaN               NaN     NaN  ...       NaN     NaN
# 5           NaN               NaN     NaN  ...       NaN     NaN
# 6           NaN               NaN     NaN  ...       NaN     NaN
# 7           NaN               NaN     NaN  ...       NaN     NaN
# 8           NaN               NaN     NaN  ...       NaN     NaN
# 9           NaN               NaN     NaN  ...       NaN     NaN
# 10          NaN               NaN     NaN  ...       NaN     NaN
# 11          NaN               NaN     NaN  ...       NaN     NaN
# 12          NaN               NaN     NaN  ...       NaN     NaN
# 13          NaN               NaN     NaN  ...       NaN     NaN
# 14          NaN               NaN     NaN  ...       NaN     NaN
# 15          NaN               NaN     NaN  ...       NaN     NaN
# 16          NaN               NaN     NaN  ...       NaN     NaN
# 17          NaN               NaN     NaN  ...       NaN     NaN
# 18          NaN               NaN     NaN  ...       NaN     NaN
# 19          NaN               NaN     NaN  ...       NaN     NaN
#
#     watershed_code  Watershed  Commodity  \
# 0                0        NaN    CARROTS
# 1                0        NaN    CARROTS
# 2                0        NaN    CARROTS
# 3                0        NaN    CARROTS
# 4                0        NaN    CARROTS
# 5                0        NaN    CARROTS
# 6                0        NaN    CARROTS
# 7                0        NaN    CARROTS
# 8                0        NaN    CARROTS
# 9                0        NaN    CARROTS
# 10               0        NaN    CARROTS
# 11               0        NaN    CARROTS
# 12               0        NaN    CARROTS
# 13               0        NaN    CARROTS
# 14               0        NaN    CARROTS
# 15               0        NaN    CARROTS
# 16               0        NaN    CARROTS
# 17               0        NaN    CARROTS
# 18               0        NaN    CARROTS
# 19               0        NaN    CARROTS
#
#                                             Data Item Domain Domain Category  \
# 0   CARROTS, FRESH MARKET - PRICE RECEIVED, MEASUR...  TOTAL   NOT SPECIFIED
# 1   CARROTS, FRESH MARKET - PRICE RECEIVED, MEASUR...  TOTAL   NOT SPECIFIED
# 2   CARROTS, FRESH MARKET - PRICE RECEIVED, MEASUR...  TOTAL   NOT SPECIFIED
# 3   CARROTS, FRESH MARKET - PRICE RECEIVED, MEASUR...  TOTAL   NOT SPECIFIED
# 4   CARROTS, FRESH MARKET - PRICE RECEIVED, MEASUR...  TOTAL   NOT SPECIFIED
# 5   CARROTS, FRESH MARKET - PRICE RECEIVED, MEASUR...  TOTAL   NOT SPECIFIED
# 6   CARROTS, FRESH MARKET - PRICE RECEIVED, MEASUR...  TOTAL   NOT SPECIFIED
# 7   CARROTS, FRESH MARKET - PRICE RECEIVED, MEASUR...  TOTAL   NOT SPECIFIED
# 8   CARROTS, FRESH MARKET - PRICE RECEIVED, MEASUR...  TOTAL   NOT SPECIFIED
# 9   CARROTS, FRESH MARKET - PRICE RECEIVED, MEASUR...  TOTAL   NOT SPECIFIED
# 10  CARROTS, FRESH MARKET - PRICE RECEIVED, MEASUR...  TOTAL   NOT SPECIFIED
# 11  CARROTS, FRESH MARKET - PRICE RECEIVED, MEASUR...  TOTAL   NOT SPECIFIED
# 12  CARROTS, FRESH MARKET - PRICE RECEIVED, MEASUR...  TOTAL   NOT SPECIFIED
# 13  CARROTS, FRESH MARKET - PRICE RECEIVED, MEASUR...  TOTAL   NOT SPECIFIED
# 14      CARROTS - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 15      CARROTS - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 16      CARROTS - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 17      CARROTS - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 18      CARROTS - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 19      CARROTS - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
#
#    Value  CV (%)
# 0   12.2     NaN
# 1   16.8     NaN
# 2   13.1     NaN
# 3   17.1     NaN
# 4   19.1     NaN
# 5   19.0     NaN
# 6   20.3     NaN
# 7   21.0     NaN
# 8   20.6     NaN
# 9   22.1     NaN
# 10  24.5     NaN
# 11  25.2     NaN
# 12  26.2     NaN
# 13  33.1     NaN
# 14  24.8     NaN
# 15  22.5     NaN
# 16  16.0     NaN
# 17  23.0     NaN
# 18  26.9     NaN
# ...
# 3                0        NaN   POTATOES
# 4                0        NaN   POTATOES
# 5                0        NaN   POTATOES
# 6                0        NaN   POTATOES
# 7                0        NaN   POTATOES
# 8                0        NaN   POTATOES
# 9                0        NaN   POTATOES
# 10               0        NaN   POTATOES
# 11               0        NaN   POTATOES
# 12               0        NaN   POTATOES
# 13               0        NaN   POTATOES
# 14               0        NaN   POTATOES
# 15               0        NaN   POTATOES
# 16               0        NaN   POTATOES
# 17               0        NaN   POTATOES
# 18               0        NaN   POTATOES
# 19               0        NaN   POTATOES
# 20               0        NaN   POTATOES
# 21               0        NaN   POTATOES
# 22               0        NaN   POTATOES
# 23               0        NaN   POTATOES
# 24               0        NaN   POTATOES
# 25               0        NaN   POTATOES
# 26               0        NaN   POTATOES
# 27               0        NaN   POTATOES
# 28               0        NaN   POTATOES
# 29               0        NaN   POTATOES
# 30               0        NaN   POTATOES
# 31               0        NaN   POTATOES
#
#                                          Data Item Domain Domain Category  \
# 0   POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 1   POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 2   POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 3   POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 4   POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 5   POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 6   POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 7   POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 8   POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 9   POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 10  POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 11  POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 12  POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 13  POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 14  POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 15  POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 16  POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 17  POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 18  POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 19  POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 20  POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 21  POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 22  POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 23  POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 24  POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 25  POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 26  POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 27  POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 28  POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 29  POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 30  POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
# 31  POTATOES - PRICE RECEIVED, MEASURED IN $ / CWT  TOTAL   NOT SPECIFIED
#
#     Value  CV (%)
# 0    6.08     NaN
# 1    4.96     NaN
# 2    5.52     NaN
# 3    6.16     NaN
# 4    5.56     NaN
# 5    6.75     NaN
# 6    4.91     NaN
# 7    5.64     NaN
# 8    5.56     NaN
# 9    5.76     NaN
# 10   5.08     NaN
# 11   6.99     NaN
# 12   6.67     NaN
# 13   5.88     NaN
# 14   5.65     NaN
# 15   7.04     NaN
# 16   7.31     NaN
# 17   7.51     NaN
# 18   9.09     NaN
# 19   8.25     NaN
# 20   9.20     NaN
# 21   9.41     NaN
# 22   8.63     NaN
# 23   9.88     NaN
# 24   8.97     NaN
# 25   8.79     NaN
# 26   9.08     NaN
# 27   9.17     NaN
# 28   8.90     NaN
# 29   9.94     NaN
# 30   9.30     NaN
# 31  10.20     NaN
#
# [32 rows x 21 columns]
#
#  ----------------------------------Fungicide Price.csv--------------------------------------------------------------
#    Program  Year          Period  Week Ending Geo Level     State  State ANSI  \
# 0   SURVEY  2001             APR          NaN  NATIONAL  US TOTAL         NaN
# 1   SURVEY  2002            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 2   SURVEY  2003            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 3   SURVEY  2004            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 4   SURVEY  2005            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 5   SURVEY  2006            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 6   SURVEY  2007            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 7   SURVEY  2008            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 8   SURVEY  2009  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 9   SURVEY  2010  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 10  SURVEY  2011  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 11  SURVEY  2012  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 12  SURVEY  2013  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 13  SURVEY  2014  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
#
#     Ag District  Ag District Code  County  ...  Zip Code  Region  \
# 0           NaN               NaN     NaN  ...       NaN     NaN
# 1           NaN               NaN     NaN  ...       NaN     NaN
# 2           NaN               NaN     NaN  ...       NaN     NaN
# 3           NaN               NaN     NaN  ...       NaN     NaN
# 4           NaN               NaN     NaN  ...       NaN     NaN
# 5           NaN               NaN     NaN  ...       NaN     NaN
# 6           NaN               NaN     NaN  ...       NaN     NaN
# 7           NaN               NaN     NaN  ...       NaN     NaN
# 8           NaN               NaN     NaN  ...       NaN     NaN
# 9           NaN               NaN     NaN  ...       NaN     NaN
# 10          NaN               NaN     NaN  ...       NaN     NaN
# 11          NaN               NaN     NaN  ...       NaN     NaN
# 12          NaN               NaN     NaN  ...       NaN     NaN
# 13          NaN               NaN     NaN  ...       NaN     NaN
#
#     watershed_code  Watershed   Commodity  \
# 0                0        NaN  FUNGICIDES
# 1                0        NaN  FUNGICIDES
# 2                0        NaN  FUNGICIDES
# 3                0        NaN  FUNGICIDES
# 4                0        NaN  FUNGICIDES
# 5                0        NaN  FUNGICIDES
# 6                0        NaN  FUNGICIDES
# 7                0        NaN  FUNGICIDES
# 8                0        NaN  FUNGICIDES
# 9                0        NaN  FUNGICIDES
# 10               0        NaN  FUNGICIDES
# 11               0        NaN  FUNGICIDES
# 12               0        NaN  FUNGICIDES
# 13               0        NaN  FUNGICIDES
#
#                                             Data Item Domain Domain Category  \
# 0   FUNGICIDES, CHLOROTHALONIL (BRAVO) 6#/GAL EC -...  TOTAL   NOT SPECIFIED
# 1   FUNGICIDES, CHLOROTHALONIL (BRAVO) 6#/GAL EC -...  TOTAL   NOT SPECIFIED
# 2   FUNGICIDES, CHLOROTHALONIL (BRAVO) 6#/GAL EC -...  TOTAL   NOT SPECIFIED
# 3   FUNGICIDES, CHLOROTHALONIL (BRAVO) 6#/GAL EC -...  TOTAL   NOT SPECIFIED
# 4   FUNGICIDES, CHLOROTHALONIL (BRAVO) 6#/GAL EC -...  TOTAL   NOT SPECIFIED
# 5   FUNGICIDES, CHLOROTHALONIL (BRAVO) 6#/GAL EC -...  TOTAL   NOT SPECIFIED
# 6   FUNGICIDES, CHLOROTHALONIL (BRAVO) 6#/GAL EC -...  TOTAL   NOT SPECIFIED
# 7   FUNGICIDES, CHLOROTHALONIL (BRAVO) 6#/GAL EC -...  TOTAL   NOT SPECIFIED
# 8   FUNGICIDES, CHLOROTHALONIL (BRAVO) 6#/GAL EC -...  TOTAL   NOT SPECIFIED
# 9   FUNGICIDES, CHLOROTHALONIL (BRAVO) 6#/GAL EC -...  TOTAL   NOT SPECIFIED
# 10  FUNGICIDES, CHLOROTHALONIL (BRAVO) 6#/GAL EC -...  TOTAL   NOT SPECIFIED
# 11  FUNGICIDES, CHLOROTHALONIL (BRAVO) 6#/GAL EC -...  TOTAL   NOT SPECIFIED
# 12  FUNGICIDES, CHLOROTHALONIL (BRAVO) 6#/GAL EC -...  TOTAL   NOT SPECIFIED
# 13  FUNGICIDES, CHLOROTHALONIL (BRAVO) 6#/GAL EC -...  TOTAL   NOT SPECIFIED
#
#    Value  CV (%)
# 0   56.1     NaN
# 1   49.7     NaN
# 2   47.2     NaN
# 3   47.4     NaN
# 4   45.2     NaN
# 5   46.7     NaN
# 6   47.0     NaN
# 7   48.2     NaN
# 8   59.8     NaN
# 9   50.0     NaN
# 10  40.8     NaN
# 11  43.8     NaN
# 12  45.3     NaN
# 13  47.2     NaN
#
# [14 rows x 21 columns]
#
#  ----------------------------------Herbicide Price.csv--------------------------------------------------------------
#   Program  Year Period  Week Ending Geo Level     State  State ANSI  \
# 0  SURVEY  2002   YEAR          NaN  NATIONAL  US TOTAL         NaN
# 1  SURVEY  2003   YEAR          NaN  NATIONAL  US TOTAL         NaN
# 2  SURVEY  2004   YEAR          NaN  NATIONAL  US TOTAL         NaN
# 3  SURVEY  2005   YEAR          NaN  NATIONAL  US TOTAL         NaN
# 4  SURVEY  2006   YEAR          NaN  NATIONAL  US TOTAL         NaN
# 5  SURVEY  2007   YEAR          NaN  NATIONAL  US TOTAL         NaN
# 6  SURVEY  2008   YEAR          NaN  NATIONAL  US TOTAL         NaN
#
#    Ag District  Ag District Code  County  ...  Zip Code  Region  \
# 0          NaN               NaN     NaN  ...       NaN     NaN
# 1          NaN               NaN     NaN  ...       NaN     NaN
# 2          NaN               NaN     NaN  ...       NaN     NaN
# 3          NaN               NaN     NaN  ...       NaN     NaN
# 4          NaN               NaN     NaN  ...       NaN     NaN
# 5          NaN               NaN     NaN  ...       NaN     NaN
# 6          NaN               NaN     NaN  ...       NaN     NaN
#
#    watershed_code  Watershed   Commodity  \
# 0               0        NaN  HERBICIDES
# 1               0        NaN  HERBICIDES
# 2               0        NaN  HERBICIDES
# 3               0        NaN  HERBICIDES
# 4               0        NaN  HERBICIDES
# 5               0        NaN  HERBICIDES
# 6               0        NaN  HERBICIDES
#
#                                            Data Item Domain Domain Category  \
# 0  HERBICIDES, GLYPHOSATE (ROUNDUP) 4#/GAL EC - P...  TOTAL   NOT SPECIFIED
# 1  HERBICIDES, GLYPHOSATE (ROUNDUP) 4#/GAL EC - P...  TOTAL   NOT SPECIFIED
# 2  HERBICIDES, GLYPHOSATE (ROUNDUP) 4#/GAL EC - P...  TOTAL   NOT SPECIFIED
# 3  HERBICIDES, GLYPHOSATE (ROUNDUP) 4#/GAL EC - P...  TOTAL   NOT SPECIFIED
# 4  HERBICIDES, GLYPHOSATE (ROUNDUP) 4#/GAL EC - P...  TOTAL   NOT SPECIFIED
# 5  HERBICIDES, GLYPHOSATE (ROUNDUP) 4#/GAL EC - P...  TOTAL   NOT SPECIFIED
# 6  HERBICIDES, GLYPHOSATE (ROUNDUP) 4#/GAL EC - P...  TOTAL   NOT SPECIFIED
#
#   Value  CV (%)
# 0  43.5     NaN
# 1  43.3     NaN
# 2  39.7     NaN
# 3  33.8     NaN
# 4  29.3     NaN
# 5  28.9     NaN
# 6  40.5     NaN
#
# [7 rows x 21 columns]
#
#  ----------------------------------Pesticide Price.csv--------------------------------------------------------------
#    Program  Year          Period  Week Ending Geo Level     State  State ANSI  \
# 0   SURVEY  2001             APR          NaN  NATIONAL  US TOTAL         NaN
# 1   SURVEY  2002            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 2   SURVEY  2003            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 3   SURVEY  2004            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 4   SURVEY  2005            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 5   SURVEY  2006            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 6   SURVEY  2007            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 7   SURVEY  2008            YEAR          NaN  NATIONAL  US TOTAL         NaN
# 8   SURVEY  2009  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 9   SURVEY  2010  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 10  SURVEY  2011  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 11  SURVEY  2012  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 12  SURVEY  2013  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
# 13  SURVEY  2014  MARKETING YEAR          NaN  NATIONAL  US TOTAL         NaN
#
#     Ag District  Ag District Code  County  ...  Zip Code  Region  \
# 0           NaN               NaN     NaN  ...       NaN     NaN
# 1           NaN               NaN     NaN  ...       NaN     NaN
# 2           NaN               NaN     NaN  ...       NaN     NaN
# 3           NaN               NaN     NaN  ...       NaN     NaN
# 4           NaN               NaN     NaN  ...       NaN     NaN
# 5           NaN               NaN     NaN  ...       NaN     NaN
# 6           NaN               NaN     NaN  ...       NaN     NaN
# 7           NaN               NaN     NaN  ...       NaN     NaN
# 8           NaN               NaN     NaN  ...       NaN     NaN
# 9           NaN               NaN     NaN  ...       NaN     NaN
# 10          NaN               NaN     NaN  ...       NaN     NaN
# 11          NaN               NaN     NaN  ...       NaN     NaN
# 12          NaN               NaN     NaN  ...       NaN     NaN
# 13          NaN               NaN     NaN  ...       NaN     NaN
#
#     watershed_code  Watershed     Commodity  \
# 0                0        NaN  INSECTICIDES
# 1                0        NaN  INSECTICIDES
# 2                0        NaN  INSECTICIDES
# 3                0        NaN  INSECTICIDES
# 4                0        NaN  INSECTICIDES
# 5                0        NaN  INSECTICIDES
# 6                0        NaN  INSECTICIDES
# 7                0        NaN  INSECTICIDES
# 8                0        NaN  INSECTICIDES
# 9                0        NaN  INSECTICIDES
# 10               0        NaN  INSECTICIDES
# 11               0        NaN  INSECTICIDES
# 12               0        NaN  INSECTICIDES
# 13               0        NaN  INSECTICIDES
#
#                                             Data Item Domain Domain Category  \
# 0   INSECTICIDES, CYFLUTHRIN (BAYTHROID) 2#/GAL EC...  TOTAL   NOT SPECIFIED
# 1   INSECTICIDES, CYFLUTHRIN (BAYTHROID) 2#/GAL EC...  TOTAL   NOT SPECIFIED
# 2   INSECTICIDES, CYFLUTHRIN (BAYTHROID) 2#/GAL EC...  TOTAL   NOT SPECIFIED
# 3   INSECTICIDES, CYFLUTHRIN (BAYTHROID) 2#/GAL EC...  TOTAL   NOT SPECIFIED
# 4   INSECTICIDES, CYFLUTHRIN (BAYTHROID) 2#/GAL EC...  TOTAL   NOT SPECIFIED
# 5   INSECTICIDES, CYFLUTHRIN (BAYTHROID) 2#/GAL EC...  TOTAL   NOT SPECIFIED
# 6   INSECTICIDES, CYFLUTHRIN (BAYTHROID) 2#/GAL EC...  TOTAL   NOT SPECIFIED
# 7   INSECTICIDES, CYFLUTHRIN (BAYTHROID) 2#/GAL EC...  TOTAL   NOT SPECIFIED
# 8   INSECTICIDES, CYFLUTHRIN (BAYTHROID) 2#/GAL EC...  TOTAL   NOT SPECIFIED
# 9   INSECTICIDES, CYFLUTHRIN (BAYTHROID) 2#/GAL EC...  TOTAL   NOT SPECIFIED
# 10  INSECTICIDES, CYFLUTHRIN (BAYTHROID) 2#/GAL EC...  TOTAL   NOT SPECIFIED
# 11  INSECTICIDES, CYFLUTHRIN (BAYTHROID) 2#/GAL EC...  TOTAL   NOT SPECIFIED
# 12  INSECTICIDES, CYFLUTHRIN (BAYTHROID) 2#/GAL EC...  TOTAL   NOT SPECIFIED
# 13  INSECTICIDES, CYFLUTHRIN (BAYTHROID) 2#/GAL EC...  TOTAL   NOT SPECIFIED
#
#    Value  CV (%)
# 0    493     NaN
# 1    397     NaN
# 2    388     NaN
# 3    362     NaN
# 4    379     NaN
# 5    373     NaN
# 6    364     NaN
# 7    320     NaN
# 8    326     NaN
# 9    310     NaN
# 10   294     NaN
# 11   302     NaN
# 12   303     NaN
# 13   308     NaN
#
# [14 rows x 21 columns]

# %% [raw]
# # OBSERVATION
#
# As seen above, the raw data is very messy:
#
# -Many irrelevant columns (We only need to look at YEAR and Value)
# -Data in YEAR column is in the incorrect format (has decimal places) and there are rows of different data for the same year
# -Data in the Value column is in the incorrect format(has commas -> currently a string datatype instead of int) and some NaN present
# -the name 'Value' is a meaningless column name that is consistent across all files, hence will cause issues when merging these different tables together

# %% [markdown]
# ### Features and Target Preparation
#
# Describe here what are the features you use and why these features. Put any Python codes to prepare and clean up your features.
#
# Do the same thing for the target. Describe your target and put any codes to prepare your target.

# %% [raw]
# Features:
# -amount of pesticide used on this crop type across the whole of US (lb)
# -amount of herbicide used on this crop type across the whole of US (lb)
# -amount of fungicide used on this crop type across the whole of US (lb)
# -price of pesticide (USD/ gallon)
# -price of herbicide (USD/ gallon)
# -price of fungicide (USD/ gallon)
#
# Target:
# -price of crop (USD/tonne)

# %% [raw]
# Overview of steps we took to create the final table with cleaned data:
#
# -Remove irrelevant columns (except YEAR and Value)
# -rename the value column
# -fix formatting of value column and drop any rows with NaN values
# -replace all instance of rows with same year with a single row containing avg value
# -finally fix formatting of year column

# %%
#remove irrelevant columns and rename value column

targetColumns=["Year","Value"]

#I created this function so that i do not have to repeat the same set of steps for each csv 
def getColumns(filename,columns):
    df=pd.read_csv(filename).loc[:,targetColumns]
    newName=filename[:-4] # this is to rename the'value' column to file name dynamically; i named the filename as the column name for my convenience
    df=df.rename(columns={"Value":newName})
    return df


#all dataframes created  
broccoliF_df=getColumns("Broccoli Fungicide.csv",targetColumns)
broccoliH_df=getColumns("Broccoli Herbicide.csv",targetColumns)
broccoliP_df=getColumns("Broccoli Pesticide.csv",targetColumns)
broccoliPrice_df=getColumns("Broccoli Price.csv",targetColumns)

carrotF_df=getColumns("Carrot Fungicide.csv",targetColumns)
carrotH_df=getColumns("Carrot Herbicide.csv",targetColumns)
carrotP_df=getColumns("Carrot Pesticide.csv",targetColumns)
carrotPrice_df=getColumns("Carrot Price.csv",targetColumns)

cornF_df=getColumns("Corn Fungicide.csv",targetColumns)
cornH_df=getColumns("Corn Herbicide.csv",targetColumns)
cornP_df=getColumns("Corn Pesticide.csv",targetColumns)
cornPrice_df=getColumns("Corn Price.csv",targetColumns)

cucumberF_df=getColumns("Cucumber Fungicide.csv",targetColumns)
cucumberH_df=getColumns("Cucumber Herbicide.csv",targetColumns)
cucumberP_df=getColumns("Cucumber Pesticide.csv",targetColumns)
cucumberPrice_df=getColumns("Cucumber Price.csv",targetColumns)

potatoF_df=getColumns("Potato Fungicide.csv",targetColumns)
potatoH_df=getColumns("Potato Herbicide.csv",targetColumns)
potatoP_df=getColumns("Potato Pesticide.csv",targetColumns)
potatoPrice_df=getColumns("Potato Price.csv",targetColumns)

fungicidePrice_df=getColumns("Fungicide Price.csv",targetColumns)
pesticidePrice_df=getColumns("Herbicide Price.csv",targetColumns)
herbicidePrice_df=getColumns("Pesticide Price.csv",targetColumns)

# %%
#functions to clean data

def convertValueToFloatOrNaN(stringVal):
    
    #if contains alphabets e.g "(D)" replace with NaN to be removed later
    if type(stringVal)==str and any(c.isalpha() for c in stringVal):
        return np.nan
    
    #to tackle values with commas e.g 5,000
    elif type(stringVal)==str and "," in stringVal:
        stringVal=stringVal.replace(",","")        
    return float(stringVal) #return float to account for values which may be in float

def removeDecimalYear(stringVal):
    stringVal=int(stringVal)
    return stringVal


def cleanData(df):
    
    valueName=df.columns[1] #to get the name of the column containing the variable (which is not year) 

    df[valueName]=df[valueName].apply(convertValueToFloatOrNaN)
    #print("-----------------convert variable to float or NaN dataframe-------------- \n",df)
    
    df=df.dropna() 
    
    
    no_duplicates=df.drop_duplicates(subset=['Year'],keep=False) #to find years that are not repeated
    #print("-----------------unduplicated years dataframe-------------- \n",no_duplicates)

    duplicated_years=set(df["Year"])-set(no_duplicates["Year"])#to find set of years that are repeated
    #print("duplicated yrs: ",duplicated_years)

    
    final_df=df.drop_duplicates(subset=['Year'],keep="first")#keep first occurence for ea yr & replace with avg values across row of same yr
    #print("-----------------dropped duplicates dataframe-------------- \n",final_df)

    for year in duplicated_years:
        duplicatedYr=df.loc[df['Year']==year] #get df of all rows with that specific yr to find avg of column
        #print(f"--------duplicated rows in year {year} ---------- \n", duplicatedYr)
        
        avg=duplicatedYr[valueName].mean()
        #print("avg: ",avg)
        
        final_df.loc[df['Year']==year,valueName]=avg
        #print(f"currently replacing {year}")
    #print("-----------------replacement with avg value for row of duplicated dataframe-------------- \n",final_df)

    final_df["Year"]=final_df["Year"].apply(removeDecimalYear) #fix year formatting
    #print("-----------------final dataframe-------------- \n",final_df)
    return final_df

# %%
#execution of code to clean each dataframe before merging them together

list_of_df=[
broccoliF_df,
broccoliH_df,
broccoliP_df,
carrotF_df,
carrotH_df,
carrotP_df,
cornF_df,
cornH_df,
cornP_df,
cucumberF_df,
cucumberH_df,
cucumberP_df,
potatoF_df,
potatoH_df,
potatoP_df,
broccoliPrice_df,
carrotPrice_df,
cornPrice_df,
cucumberPrice_df,
potatoPrice_df,
fungicidePrice_df,
pesticidePrice_df,
herbicidePrice_df,

    
]

for index in range(len(list_of_df)):
    list_of_df[index]=cleanData(list_of_df[index])
    display(list_of_df[index])
# Out:
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# <ipython-input-4-bf30ce00a8b3>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Year"]=final_df["Year"].apply(removeDecimalYear) #fix year formatting
#     Year  Broccoli Fungicide
# 0   1992         9433.333333
# 4   1994        47500.000000
# 5   1998        36700.000000
# 6   2000        25900.000000
# 7   2006        15300.000000
# 8   2010        40700.000000
# 9   2014        48500.000000
# 10  2016        37400.000000
# 11  2018        89100.000000
# 12  2020        59900.000000
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# <ipython-input-4-bf30ce00a8b3>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Year"]=final_df["Year"].apply(removeDecimalYear) #fix year formatting
#     Year  Broccoli Herbicide
# 0   1992             42800.0
# 6   1994            242100.0
# 7   1998            177400.0
# 8   2000            234300.0
# 9   2006            218900.0
# 10  2010            133000.0
# 11  2014            228400.0
# 12  2016            135100.0
# 13  2018            110300.0
# 14  2020             83400.0
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# <ipython-input-4-bf30ce00a8b3>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Year"]=final_df["Year"].apply(removeDecimalYear) #fix year formatting
#     Year  Broccoli Pesticide
# 0   1992             17540.0
# 16  1994            286900.0
# 17  1998            176800.0
# 18  2000            270100.0
# 19  2006            180500.0
# 20  2010            121300.0
# 21  2014            120500.0
# 22  2016             69000.0
# 23  2018            101300.0
# 24  2020             50800.0
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# <ipython-input-4-bf30ce00a8b3>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Year"]=final_df["Year"].apply(removeDecimalYear) #fix year formatting
#    Year  Carrot Fungicide
# 0  2020          893200.0
# 1  2018          671600.0
# 2  1996          469100.0
# 3  1994          483400.0
# 4  1992          114500.0
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# <ipython-input-4-bf30ce00a8b3>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Year"]=final_df["Year"].apply(removeDecimalYear) #fix year formatting
#    Year  Carrot Herbicide
# 0  2020          116000.0
# 1  2018           57300.0
# 2  1996          153200.0
# 3  1994          117000.0
# 4  1992           22275.0
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# <ipython-input-4-bf30ce00a8b3>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Year"]=final_df["Year"].apply(removeDecimalYear) #fix year formatting
#    Year  Carrot Pesticide
# 0  2020            4700.0
# 1  2018            4500.0
# 2  1996           55900.0
# 3  1994           57700.0
# 4  1992            7000.0
#    Year  Corn Fungicide
# 0  1995         17000.0
# 1  1997         14000.0
# 2  2003        232000.0
# 3  2005         93000.0
# 4  2010        744000.0
# 5  2014       1162000.0
# 6  2016       1329000.0
# 7  2018       3775000.0
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# <ipython-input-4-bf30ce00a8b3>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Year"]=final_df["Year"].apply(removeDecimalYear) #fix year formatting
#     Year  Corn Herbicide
# 0   2021    2.378180e+08
# 1   2018    2.147210e+08
# 2   2016    2.260420e+08
# 3   2014    1.762910e+08
# 4   2010    1.821500e+08
# 5   2005    1.575750e+08
# 6   2003    1.491360e+08
# 7   2002    9.577700e+07
# 8   2001    1.572390e+08
# 9   2000    1.534640e+08
# 10  1999    1.540590e+08
# 11  1998    1.770120e+08
# 12  1997    1.640510e+08
# 13  1996    1.869770e+08
# 14  1995    1.676420e+08
# 15  1994    1.702210e+08
# 16  1993    9.093800e+06
# 37  1992    9.954200e+06
# 58  1991    9.022333e+06
# 80  1990    2.309444e+07
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# <ipython-input-4-bf30ce00a8b3>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Year"]=final_df["Year"].apply(removeDecimalYear) #fix year formatting
#     Year  Corn Pesticide
# 0   1994    1.369500e+07
# 1   1995    1.345700e+07
# 2   1996    1.421800e+07
# 3   1997    1.357000e+07
# 4   1998    1.211800e+07
# 5   1999    1.011500e+07
# 6   2000    9.811000e+06
# 7   2001    9.004000e+06
# 8   2002    3.931000e+06
# 9   2003    7.465000e+06
# 10  2005    4.849000e+06
# 11  2010    1.631000e+06
# 12  2014    1.684000e+06
# 13  2016    1.922000e+06
# 14  2018    2.087000e+06
# 15  2021    1.099000e+06
# 17  1993    2.079750e+06
# 26  1992    1.533500e+06
# 39  1991    1.395467e+06
# 55  1990    5.327250e+06
#    Year  Cucumber Fungicide
# 0  2020            616300.0
# 1  2018            527500.0
#    Year  Cucumber Herbicide
# 0  2020            101800.0
# 1  2018             32100.0
#    Year  Cucumber Pesticide
# 0  2020             23600.0
# 1  2018             51600.0
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# <ipython-input-4-bf30ce00a8b3>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Year"]=final_df["Year"].apply(removeDecimalYear) #fix year formatting
#     Year  Potato Fungicide
# 0   1990      7.988889e+04
# 10  1991      2.352727e+05
# 22  1992      2.492500e+05
# 35  1993      4.191250e+05
# 44  1994      5.104000e+06
# 45  1995      6.546000e+06
# 46  1996      3.929000e+06
# 47  1997      7.455000e+06
# 48  1998      1.217000e+06
# 49  1999      7.170000e+06
# 50  2001      5.196000e+06
# 51  2003      6.538000e+06
# 52  2005      5.534000e+06
# 53  2010      5.367000e+06
# 54  2014      6.018000e+06
# 55  2016      6.965000e+06
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# <ipython-input-4-bf30ce00a8b3>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Year"]=final_df["Year"].apply(removeDecimalYear) #fix year formatting
#     Year  Potato Herbicide
# 0   1990      1.774545e+05
# 12  1991      2.557500e+05
# 21  1992      2.140000e+05
# 30  1993      2.402500e+05
# 39  1994      2.301000e+06
# 40  1995      2.376000e+06
# 41  1996      1.577000e+06
# 42  1997      1.646000e+06
# 43  1998      1.210000e+05
# 44  1999      2.047000e+06
# 45  2001      1.359000e+06
# 46  2003      1.577000e+06
# 47  2005      1.394000e+06
# 48  2010      1.672000e+06
# 49  2014      1.683000e+06
# 50  2016      1.874000e+06
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# <ipython-input-4-bf30ce00a8b3>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Year"]=final_df["Year"].apply(removeDecimalYear) #fix year formatting
#      Year  Potato Pesticide
# 0    1990      1.457368e+05
# 20   1991      1.264348e+05
# 44   1992      1.285000e+05
# 67   1993      1.375455e+05
# 90   1994      3.580000e+06
# 91   1995      2.553000e+06
# 92   1996      1.370000e+06
# 93   1997      2.287000e+06
# 94   1998      1.510000e+05
# 95   1999      2.596000e+06
# 96   2001      1.862000e+06
# 97   2003      1.571000e+06
# 98   2005      9.790000e+05
# 99   2010      7.500000e+05
# 100  2014      8.920000e+05
# 101  2016      4.020000e+05
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\garta\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# <ipython-input-4-bf30ce00a8b3>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Year"]=final_df["Year"].apply(removeDecimalYear) #fix year formatting
#     Year  Broccoli Price
# 0   1996           27.10
# 1   1997           28.50
# 2   1998           29.85
# 4   1999           24.00
# 6   2000           30.50
# 7   2001           25.90
# 8   2002           30.90
# 9   2003           31.60
# 10  2004           32.10
# 11  2005           28.50
# 12  2006           33.30
# 14  2007           36.20
# 16  2008           35.90
# 18  2009           39.90
# 20  2010           36.65
# 22  2011           35.15
# 24  2012           33.60
# 25  2013           42.80
# 26  2014           40.00
# 27  2015           48.40
# 28  2016           37.70
# 29  2017           45.40
# 30  2018           42.80
# 31  2019           51.30
# 32  2020           55.50
# 33  2021           52.20
#     Year  Carrot Price
# 0   1998          12.2
# 1   1999          16.8
# 2   2000          13.1
# 3   2001          17.1
# 4   2002          19.1
# 5   2003          19.0
# 6   2004          20.3
# 7   2005          21.0
# 8   2006          20.6
# 9   2007          22.1
# 10  2008          24.5
# 11  2009          25.2
# 12  2010          26.2
# 13  2011          33.1
# 14  2016          24.8
# 15  2017          22.5
# 16  2018          16.0
# 17  2019          23.0
# 18  2020          26.9
# 19  2021          26.3
#     Year  Corn Price
# 0   1996        3.55
# 1   1997        2.60
# 2   1998        2.20
# 3   1999        1.89
# 4   2000        1.86
# 5   2001        1.89
# 6   2002        2.13
# 7   2003        2.27
# 8   2004        2.47
# 9   2005        1.96
# 10  2006        2.28
# 11  2007        3.39
# 12  2008        4.78
# 13  2009        3.75
# 14  2010        3.83
# 15  2011        6.02
# 16  2012        6.67
# 17  2013        6.15
# 18  2014        4.11
# 19  2015        3.71
# 20  2016        3.48
# 21  2017        3.36
# 22  2018        3.47
# 23  2019        3.75
# 24  2020        3.50
# 25  2021        5.40
#     Year  Cucumber Price
# 0   1998            20.0
# 1   1999            18.2
# 2   2000            19.9
# 3   2001            19.8
# 4   2002            19.0
# 5   2003            19.9
# 6   2004            20.2
# 7   2005            23.1
# 8   2006            25.3
# 9   2007            24.6
# 10  2008            24.8
# 11  2009            25.6
# 12  2010            22.8
# 13  2011            26.6
# 14  2016            19.9
# 15  2017            20.8
# 16  2018            20.9
# 17  2019            18.8
# 18  2020            18.3
# 19  2021            18.2
#     Year  Potato Price
# 0   1990          6.08
# 1   1991          4.96
# 2   1992          5.52
# 3   1993          6.16
# 4   1994          5.56
# 5   1995          6.75
# 6   1996          4.91
# 7   1997          5.64
# 8   1998          5.56
# 9   1999          5.76
# 10  2000          5.08
# 11  2001          6.99
# 12  2002          6.67
# 13  2003          5.88
# 14  2004          5.65
# 15  2005          7.04
# 16  2006          7.31
# 17  2007          7.51
# 18  2008          9.09
# 19  2009          8.25
# 20  2010          9.20
# 21  2011          9.41
# 22  2012          8.63
# 23  2013          9.88
# 24  2014          8.97
# 25  2015          8.79
# 26  2016          9.08
# 27  2017          9.17
# 28  2018          8.90
# 29  2019          9.94
# 30  2020          9.30
# 31  2021         10.20
#     Year  Fungicide Price
# 0   2001             56.1
# 1   2002             49.7
# 2   2003             47.2
# 3   2004             47.4
# 4   2005             45.2
# 5   2006             46.7
# 6   2007             47.0
# 7   2008             48.2
# 8   2009             59.8
# 9   2010             50.0
# 10  2011             40.8
# 11  2012             43.8
# 12  2013             45.3
# 13  2014             47.2
#    Year  Herbicide Price
# 0  2002             43.5
# 1  2003             43.3
# 2  2004             39.7
# 3  2005             33.8
# 4  2006             29.3
# 5  2007             28.9
# 6  2008             40.5
#     Year  Pesticide Price
# 0   2001            493.0
# 1   2002            397.0
# 2   2003            388.0
# 3   2004            362.0
# 4   2005            379.0
# 5   2006            373.0
# 6   2007            364.0
# 7   2008            320.0
# 8   2009            326.0
# 9   2010            310.0
# 10  2011            294.0
# 11  2012            302.0
# 12  2013            303.0
# 13  2014            308.0

# %%
#merge individual dframes to form complete df

combined_df=list_of_df[0]
for df in list_of_df[1:]:
    combined_df=combined_df.merge(df, how='outer', on='Year')#join based of union of Years column

combined_df=combined_df.sort_values(by=['Year'])
display(combined_df)
# Out:
#     Year  Broccoli Fungicide  Broccoli Herbicide  Broccoli Pesticide  \
# 21  1990                 NaN                 NaN                 NaN
# 20  1991                 NaN                 NaN                 NaN
# 0   1992         9433.333333             42800.0             17540.0
# 19  1993                 NaN                 NaN                 NaN
# 1   1994        47500.000000            242100.0            286900.0
# 11  1995                 NaN                 NaN                 NaN
# 10  1996                 NaN                 NaN                 NaN
# 12  1997                 NaN                 NaN                 NaN
# 2   1998        36700.000000            177400.0            176800.0
# 18  1999                 NaN                 NaN                 NaN
# 3   2000        25900.000000            234300.0            270100.0
# 17  2001                 NaN                 NaN                 NaN
# 16  2002                 NaN                 NaN                 NaN
# 13  2003                 NaN                 NaN                 NaN
# 22  2004                 NaN                 NaN                 NaN
# 14  2005                 NaN                 NaN                 NaN
# 4   2006        15300.000000            218900.0            180500.0
# 23  2007                 NaN                 NaN                 NaN
# 24  2008                 NaN                 NaN                 NaN
# 25  2009                 NaN                 NaN                 NaN
# 5   2010        40700.000000            133000.0            121300.0
# 26  2011                 NaN                 NaN                 NaN
# 27  2012                 NaN                 NaN                 NaN
# 28  2013                 NaN                 NaN                 NaN
# 6   2014        48500.000000            228400.0            120500.0
# 29  2015                 NaN                 NaN                 NaN
# 7   2016        37400.000000            135100.0             69000.0
# 30  2017                 NaN                 NaN                 NaN
# 8   2018        89100.000000            110300.0            101300.0
# 31  2019                 NaN                 NaN                 NaN
# 9   2020        59900.000000             83400.0             50800.0
# 15  2021                 NaN                 NaN                 NaN
#
#     Carrot Fungicide  Carrot Herbicide  Carrot Pesticide  Corn Fungicide  \
# 21               NaN               NaN               NaN             NaN
# 20               NaN               NaN               NaN             NaN
# 0           114500.0           22275.0            7000.0             NaN
# 19               NaN               NaN               NaN             NaN
# 1           483400.0          117000.0           57700.0             NaN
# 11               NaN               NaN               NaN         17000.0
# 10          469100.0          153200.0           55900.0             NaN
# 12               NaN               NaN               NaN         14000.0
# 2                NaN               NaN               NaN             NaN
# 18               NaN               NaN               NaN             NaN
# 3                NaN               NaN               NaN             NaN
# 17               NaN               NaN               NaN             NaN
# 16               NaN               NaN               NaN             NaN
# 13               NaN               NaN               NaN        232000.0
# 22               NaN               NaN               NaN             NaN
# 14               NaN               NaN               NaN         93000.0
# 4                NaN               NaN               NaN             NaN
# 23               NaN               NaN               NaN             NaN
# 24               NaN               NaN               NaN             NaN
# 25               NaN               NaN               NaN             NaN
# 5                NaN               NaN               NaN        744000.0
# 26               NaN               NaN               NaN             NaN
# 27               NaN               NaN               NaN             NaN
# 28               NaN               NaN               NaN             NaN
# 6                NaN               NaN               NaN       1162000.0
# 29               NaN               NaN               NaN             NaN
# 7                NaN               NaN               NaN       1329000.0
# 30               NaN               NaN               NaN             NaN
# 8           671600.0           57300.0            4500.0       3775000.0
# 31               NaN               NaN               NaN             NaN
# 9           893200.0          116000.0            4700.0             NaN
# 15               NaN               NaN               NaN             NaN
#
#     Corn Herbicide  Corn Pesticide  ...  Potato Herbicide  Potato Pesticide  \
# 21    2.309444e+07    5.327250e+06  ...      1.774545e+05      1.457368e+05
# 20    9.022333e+06    1.395467e+06  ...      2.557500e+05      1.264348e+05
# 0     9.954200e+06    1.533500e+06  ...      2.140000e+05      1.285000e+05
# 19    9.093800e+06    2.079750e+06  ...      2.402500e+05      1.375455e+05
# 1     1.702210e+08    1.369500e+07  ...      2.301000e+06      3.580000e+06
# 11    1.676420e+08    1.345700e+07  ...      2.376000e+06      2.553000e+06
# 10    1.869770e+08    1.421800e+07  ...      1.577000e+06      1.370000e+06
# 12    1.640510e+08    1.357000e+07  ...      1.646000e+06      2.287000e+06
# 2     1.770120e+08    1.211800e+07  ...      1.210000e+05      1.510000e+05
# 18    1.540590e+08    1.011500e+07  ...      2.047000e+06      2.596000e+06
# 3     1.534640e+08    9.811000e+06  ...               NaN               NaN
# 17    1.572390e+08    9.004000e+06  ...      1.359000e+06      1.862000e+06
# 16    9.577700e+07    3.931000e+06  ...               NaN               NaN
# 13    1.491360e+08    7.465000e+06  ...      1.577000e+06      1.571000e+06
# 22             NaN             NaN  ...               NaN               NaN
# 14    1.575750e+08    4.849000e+06  ...      1.394000e+06      9.790000e+05
# 4              NaN             NaN  ...               NaN               NaN
# 23             NaN             NaN  ...               NaN               NaN
# 24             NaN             NaN  ...               NaN               NaN
# 25             NaN             NaN  ...               NaN               NaN
# 5     1.821500e+08    1.631000e+06  ...      1.672000e+06      7.500000e+05
# 26             NaN             NaN  ...               NaN               NaN
# 27             NaN             NaN  ...               NaN               NaN
# 28             NaN             NaN  ...               NaN               NaN
# 6     1.762910e+08    1.684000e+06  ...      1.683000e+06      8.920000e+05
# 29             NaN             NaN  ...               NaN               NaN
# 7     2.260420e+08    1.922000e+06  ...      1.874000e+06      4.020000e+05
# 30             NaN             NaN  ...               NaN               NaN
# 8     2.147210e+08    2.087000e+06  ...               NaN               NaN
# 31             NaN             NaN  ...               NaN               NaN
# 9              NaN             NaN  ...               NaN               NaN
# 15    2.378180e+08    1.099000e+06  ...               NaN               NaN
#
#     Broccoli Price  Carrot Price  Corn Price  Cucumber Price  Potato Price  \
# 21             NaN           NaN         NaN             NaN          6.08
# 20             NaN           NaN         NaN             NaN          4.96
# 0              NaN           NaN         NaN             NaN          5.52
# 19             NaN           NaN         NaN             NaN          6.16
# 1              NaN           NaN         NaN             NaN          5.56
# 11             NaN           NaN         NaN             NaN          6.75
# 10           27.10           NaN        3.55             NaN          4.91
# 12           28.50           NaN        2.60             NaN          5.64
# 2            29.85          12.2        2.20            20.0          5.56
# 18           24.00          16.8        1.89            18.2          5.76
# 3            30.50          13.1        1.86            19.9          5.08
# 17           25.90          17.1        1.89            19.8          6.99
# 16           30.90          19.1        2.13            19.0          6.67
# 13           31.60          19.0        2.27            19.9          5.88
# 22           32.10          20.3        2.47            20.2          5.65
# 14           28.50          21.0        1.96            23.1          7.04
# 4            33.30          20.6        2.28            25.3          7.31
# 23           36.20          22.1        3.39            24.6          7.51
# 24           35.90          24.5        4.78            24.8          9.09
# 25           39.90          25.2        3.75            25.6          8.25
# 5            36.65          26.2        3.83            22.8          9.20
# 26           35.15          33.1        6.02            26.6          9.41
# 27           33.60           NaN        6.67             NaN          8.63
# 28           42.80           NaN        6.15             NaN          9.88
# 6            40.00           NaN        4.11             NaN          8.97
# 29           48.40           NaN        3.71             NaN          8.79
# 7            37.70          24.8        3.48            19.9          9.08
# 30           45.40          22.5        3.36            20.8          9.17
# 8            42.80          16.0        3.47            20.9          8.90
# 31           51.30          23.0        3.75            18.8          9.94
# 9            55.50          26.9        3.50            18.3          9.30
# 15           52.20          26.3        5.40            18.2         10.20
#
#     Fungicide Price  Herbicide Price  Pesticide Price
# 21              NaN              NaN              NaN
# 20              NaN              NaN              NaN
# 0               NaN              NaN              NaN
# 19              NaN              NaN              NaN
# 1               NaN              NaN              NaN
# 11              NaN              NaN              NaN
# 10              NaN              NaN              NaN
# 12              NaN              NaN              NaN
# 2               NaN              NaN              NaN
# 18              NaN              NaN              NaN
# 3               NaN              NaN              NaN
# 17             56.1              NaN            493.0
# 16             49.7             43.5            397.0
# 13             47.2             43.3            388.0
# 22             47.4             39.7            362.0
# 14             45.2             33.8            379.0
# 4              46.7             29.3            373.0
# 23             47.0             28.9            364.0
# 24             48.2             40.5            320.0
# 25             59.8              NaN            326.0
# 5              50.0              NaN            310.0
# 26             40.8              NaN            294.0
# 27             43.8              NaN            302.0
# 28             45.3              NaN            303.0
# 6              47.2              NaN            308.0
# 29              NaN              NaN              NaN
# 7               NaN              NaN              NaN
# 30              NaN              NaN              NaN
# 8               NaN              NaN              NaN
# 31              NaN              NaN              NaN
# 9               NaN              NaN              NaN
# 15              NaN              NaN              NaN
#
# [32 rows x 24 columns]

# %% [raw]
# Since our dataset is incomplete and we are unable to find full dataset containing data for all years from 1990-2021, we had to fill in the missing values using logical guesses(we tried to plot a linear graph using years with data and derive values for missing years in between) , thus we have to export and re-import again after filling the values

# %%
#combined_df.to_excel("combinedTable(3).xlsx")    -->this is commented out to prevent file conflict

# %%
#import the updated combined table
final_df=pd.read_excel("combinedTable(3).xlsx")
display(final_df) #realised first column is unnamed column
final_df=final_df.iloc[:,1:] #to remove the unnamed column
display(final_df)
# Out:
#     Unnamed: 0  Year  Broccoli Fungicide  Broccoli Herbicide  \
# 0           21  1990               28300              213000
# 1           20  1991               28300              214000
# 2            0  1992               28300              214000
# 3           19  1993               37700              150300
# 4            1  1994               47500              242100
# 5           11  1995               43300              220300
# 6           10  1996               43300              201400
# 7           12  1997               35300              180500
# 8            2  1998               36700              177400
# 9           18  1999               30500              232500
# 10           3  2000               25900              234300
# 11          17  2001               20300              200500
# 12          16  2002               15400              148900
# 13          13  2003               20000              120500
# 14          22  2004               19300              115800
# 15          14  2005               17300              134500
# 16           4  2006               15300              218900
# 17          23  2007               16300              220500
# 18          24  2008               20400              345600
# 19          25  2009               25300              254300
# 20           5  2010               40700              133000
# 21          26  2011               45300              200000
# 22          27  2012               46300              210000
# 23          28  2013               47500              234000
# 24           6  2014               48500              228400
# 25          29  2015               32500              150300
# 26           7  2016               37400              135100
# 27          30  2017               70500              123300
# 28           8  2018               89100              110300
# 29          31  2019               65300               95300
# 30           9  2020               59900               83400
# 31          15  2021               60300               75300
#
#     Broccoli Pesticide  Carrot Fungicide  Carrot Herbicide  Carrot Pesticide  \
# 0               263100            687000             89200             42000
# 1               263100            687000             89100             42000
# 2               263100            687000             89100             42000
# 3               270300            500400            100000             58300
# 4               286900            483400            117700             57700
# 5               150300            473300            160700             54900
# 6               260200            469100            153200             55900
# 7               196300            470300            160300             57300
# 8               176800            508300            154300             60400
# 9               214500            400500             90300             40300
# 10              270100            220000             88300             21000
# 11              240300            230300             90200             27000
# 12              234800            135900             90700             28000
# 13              220500            170300             75300             20000
# 14              239500            201400             51100             19000
# 15              190500            700300             90000             16000
# 16              180500           1051300             86600             15000
# 17              170500           1023300             78800             18000
# 18              150300            900600             79900             19000
# 19              135200            920300             80000             20000
# 20              121300            897300             87300             21000
# 21              120300            863500             89300             22000
# 22              119400            896500             86300             19000
# 23              100500            753800             70300             15000
# 24              120500            895300             57300             12000
# 25               90300            680300             60300              8000
# 26              696900            687300             78300              7000
# 27               90300            650600             79300              2000
# 28              101300            671600             57300              4000
# 29               98300            700400             80400              4000
# 30               50800            893200            116600              4000
# 31               51800            900500            120000              4000
#
#     Corn Fungicide  Corn Herbicide  ...  Potato Herbicide  Potato Pesticide  \
# 0            20000       207850000  ...           1952000           2769000
# 1            15000       189469000  ...           2046000           2908000
# 2            18000       199084000  ...           1712000           2827000
# 3            12000       181876000  ...           1922000           3026000
# 4            16000       170221000  ...           2301000           3580000
# 5            17000       167642000  ...           2376000           2553000
# 6            17000       186977000  ...           1577000           1370000
# 7            14000       164051000  ...           1646000           2287000
# 8            15000       177012000  ...            121000            151000
# 9            18000       154059000  ...           2047000           2596000
# 10           17000       153464000  ...           1453000           2000000
# 11           50000       157239000  ...           1359000           1862000
# 12          120000        95777000  ...           1298000           1786000
# 13          232000       149136000  ...           1577000           1571000
# 14          200000       135755000  ...           1285000           1200000
# 15           93000       157575000  ...           1394000            979000
# 16          167000       164875000  ...           1672000            750000
# 17          185000       165743000  ...           1672000            750000
# 18          300000       175583000  ...           1672000            650000
# 19          452000       181520000  ...           1672000            750000
# 20          744000       182150000  ...           1672000            750000
# 21          852000       173854000  ...           1685000            750000
# 22          912000       173896000  ...           1693000            842000
# 23         1007000       175394000  ...           1654000            872000
# 24         1162000       176291000  ...           1683000            892000
# 25         1200000       208953000  ...           1786000            675000
# 26         1329000       226042000  ...           1874000            402000
# 27         1300000       215786000  ...           1983000            403000
# 28         3775000       214721000  ...           1975000            405000
# 29         3000000       257893000  ...           1875000            597000
# 30         4562000       247893000  ...           1753000            476000
# 31         4200000       237818000  ...           1873000            487000
#
#     Broccoli Price  Carrot Price  Corn Price  Cucumber Price  Potato Price  \
# 0            17.20          15.3        3.20            23.0          6.08
# 1            28.30          14.3        3.50            23.5          4.96
# 2            18.90          12.3        2.30            34.3          5.52
# 3            21.20          16.5        3.70            28.5          6.16
# 4            22.20          17.5        2.80            27.4          5.56
# 5            24.50          14.3        2.70            26.5          6.75
# 6            27.10          18.3        3.55            24.3          4.91
# 7            28.50          18.3        2.60            20.8          5.64
# 8            29.85          12.2        2.20            20.0          5.56
# 9            24.00          16.8        1.89            18.2          5.76
# 10           30.50          13.1        1.86            19.9          5.08
# 11           25.90          17.1        1.89            19.8          6.99
# 12           30.90          19.1        2.13            19.0          6.67
# 13           31.60          19.0        2.27            19.9          5.88
# 14           32.10          20.3        2.47            20.2          5.65
# 15           28.50          21.0        1.96            23.1          7.04
# 16           33.30          20.6        2.28            25.3          7.31
# 17           36.20          22.1        3.39            24.6          7.51
# 18           35.90          24.5        4.78            24.8          9.09
# 19           39.90          25.2        3.75            25.6          8.25
# 20           36.65          26.2        3.83            22.8          9.20
# 21           35.15          33.1        6.02            26.6          9.41
# 22           33.60          35.0        6.67            27.3          8.63
# 23           42.80          24.3        6.15            19.9          9.88
# 24           40.00          24.4        4.11            20.3          8.97
# 25           48.40          25.0        3.71            20.9          8.79
# 26           37.70          24.8        3.48            19.9          9.08
# 27           45.40          22.5        3.36            20.8          9.17
# 28           42.80          16.0        3.47            20.9          8.90
# 29           51.30          23.0        3.75            18.8          9.94
# 30           55.50          26.9        3.50            18.3          9.30
# 31           52.20          26.3        5.40            18.2         10.20
#
#     Fungicide Price  Herbicide Price  Pesticide Price
# 0              53.3        37.533411       325.207018
# 1              56.0        39.573271       345.388304
# 2              54.6        40.032239       357.497076
# 3              58.0        41.613130       389.787134
# 4              48.5        43.194021       401.319298
# 5              49.6        44.570926       413.428070
# 6              50.6        45.845838       429.573099
# 7              57.4        45.845838       447.447953
# 8              57.8        46.049824       468.205848
# 9              58.5        44.468933       482.044444
# 10             59.4        43.347011       497.036257
# 11             56.1        43.754982       493.000000
# 12             49.7        43.500000       397.000000
# 13             47.2        43.300000       388.000000
# 14             47.4        39.700000       362.000000
# 15             45.2        33.800000       379.000000
# 16             46.7        29.300000       373.000000
# 17             47.0        28.900000       364.000000
# 18             48.2        40.500000       320.000000
# 19             59.8        43.871615       326.000000
# 20             50.0        41.149950       310.000000
# 21             40.8        40.621866       294.000000
# 22             43.8        43.059178       302.000000
# 23             45.3        43.871615       303.000000
# 24             47.2        44.562187       308.000000
# 25             46.3        43.627884       294.537020
# 26             44.4        44.562187       295.910794
# 27             47.3        43.221665       283.272079
# 28             49.3        41.799900       281.074041
# 29             50.3        40.459378       253.323818
# 30             51.3        39.159478       256.071365
# 31             52.3        42.774824       271.182872
#
# [32 rows x 25 columns]
#     Year  Broccoli Fungicide  Broccoli Herbicide  Broccoli Pesticide  \
# 0   1990               28300              213000              263100
# 1   1991               28300              214000              263100
# 2   1992               28300              214000              263100
# 3   1993               37700              150300              270300
# 4   1994               47500              242100              286900
# 5   1995               43300              220300              150300
# 6   1996               43300              201400              260200
# 7   1997               35300              180500              196300
# 8   1998               36700              177400              176800
# 9   1999               30500              232500              214500
# 10  2000               25900              234300              270100
# 11  2001               20300              200500              240300
# 12  2002               15400              148900              234800
# 13  2003               20000              120500              220500
# 14  2004               19300              115800              239500
# 15  2005               17300              134500              190500
# 16  2006               15300              218900              180500
# 17  2007               16300              220500              170500
# 18  2008               20400              345600              150300
# 19  2009               25300              254300              135200
# 20  2010               40700              133000              121300
# 21  2011               45300              200000              120300
# 22  2012               46300              210000              119400
# 23  2013               47500              234000              100500
# 24  2014               48500              228400              120500
# 25  2015               32500              150300               90300
# 26  2016               37400              135100              696900
# 27  2017               70500              123300               90300
# 28  2018               89100              110300              101300
# 29  2019               65300               95300               98300
# 30  2020               59900               83400               50800
# 31  2021               60300               75300               51800
#
#     Carrot Fungicide  Carrot Herbicide  Carrot Pesticide  Corn Fungicide  \
# 0             687000             89200             42000           20000
# 1             687000             89100             42000           15000
# 2             687000             89100             42000           18000
# 3             500400            100000             58300           12000
# 4             483400            117700             57700           16000
# 5             473300            160700             54900           17000
# 6             469100            153200             55900           17000
# 7             470300            160300             57300           14000
# 8             508300            154300             60400           15000
# 9             400500             90300             40300           18000
# 10            220000             88300             21000           17000
# 11            230300             90200             27000           50000
# 12            135900             90700             28000          120000
# 13            170300             75300             20000          232000
# 14            201400             51100             19000          200000
# 15            700300             90000             16000           93000
# 16           1051300             86600             15000          167000
# 17           1023300             78800             18000          185000
# 18            900600             79900             19000          300000
# 19            920300             80000             20000          452000
# 20            897300             87300             21000          744000
# 21            863500             89300             22000          852000
# 22            896500             86300             19000          912000
# 23            753800             70300             15000         1007000
# 24            895300             57300             12000         1162000
# 25            680300             60300              8000         1200000
# 26            687300             78300              7000         1329000
# 27            650600             79300              2000         1300000
# 28            671600             57300              4000         3775000
# 29            700400             80400              4000         3000000
# 30            893200            116600              4000         4562000
# 31            900500            120000              4000         4200000
#
#     Corn Herbicide  Corn Pesticide  ...  Potato Herbicide  Potato Pesticide  \
# 0        207850000        21309000  ...           1952000           2769000
# 1        189469000        20932000  ...           2046000           2908000
# 2        199084000        18402000  ...           1712000           2827000
# 3        181876000        16638000  ...           1922000           3026000
# 4        170221000        13695000  ...           2301000           3580000
# 5        167642000        13457000  ...           2376000           2553000
# 6        186977000        14218000  ...           1577000           1370000
# 7        164051000        13570000  ...           1646000           2287000
# 8        177012000        12118000  ...            121000            151000
# 9        154059000        10115000  ...           2047000           2596000
# 10       153464000         9811000  ...           1453000           2000000
# 11       157239000         9004000  ...           1359000           1862000
# 12        95777000         3931000  ...           1298000           1786000
# 13       149136000         7465000  ...           1577000           1571000
# 14       135755000         5786000  ...           1285000           1200000
# 15       157575000         4849000  ...           1394000            979000
# 16       164875000         3897000  ...           1672000            750000
# 17       165743000         3765000  ...           1672000            750000
# 18       175583000         2785000  ...           1672000            650000
# 19       181520000         2935000  ...           1672000            750000
# 20       182150000         1631000  ...           1672000            750000
# 21       173854000         1620000  ...           1685000            750000
# 22       173896000         1615000  ...           1693000            842000
# 23       175394000         1607000  ...           1654000            872000
# 24       176291000         1684000  ...           1683000            892000
# 25       208953000         1894000  ...           1786000            675000
# 26       226042000         1922000  ...           1874000            402000
# 27       215786000         2000000  ...           1983000            403000
# 28       214721000         2087000  ...           1975000            405000
# 29       257893000         1597000  ...           1875000            597000
# 30       247893000         1298000  ...           1753000            476000
# 31       237818000         1099000  ...           1873000            487000
#
#     Broccoli Price  Carrot Price  Corn Price  Cucumber Price  Potato Price  \
# 0            17.20          15.3        3.20            23.0          6.08
# 1            28.30          14.3        3.50            23.5          4.96
# 2            18.90          12.3        2.30            34.3          5.52
# 3            21.20          16.5        3.70            28.5          6.16
# 4            22.20          17.5        2.80            27.4          5.56
# 5            24.50          14.3        2.70            26.5          6.75
# 6            27.10          18.3        3.55            24.3          4.91
# 7            28.50          18.3        2.60            20.8          5.64
# 8            29.85          12.2        2.20            20.0          5.56
# 9            24.00          16.8        1.89            18.2          5.76
# 10           30.50          13.1        1.86            19.9          5.08
# 11           25.90          17.1        1.89            19.8          6.99
# 12           30.90          19.1        2.13            19.0          6.67
# 13           31.60          19.0        2.27            19.9          5.88
# 14           32.10          20.3        2.47            20.2          5.65
# 15           28.50          21.0        1.96            23.1          7.04
# 16           33.30          20.6        2.28            25.3          7.31
# 17           36.20          22.1        3.39            24.6          7.51
# 18           35.90          24.5        4.78            24.8          9.09
# 19           39.90          25.2        3.75            25.6          8.25
# 20           36.65          26.2        3.83            22.8          9.20
# 21           35.15          33.1        6.02            26.6          9.41
# 22           33.60          35.0        6.67            27.3          8.63
# 23           42.80          24.3        6.15            19.9          9.88
# 24           40.00          24.4        4.11            20.3          8.97
# 25           48.40          25.0        3.71            20.9          8.79
# 26           37.70          24.8        3.48            19.9          9.08
# 27           45.40          22.5        3.36            20.8          9.17
# 28           42.80          16.0        3.47            20.9          8.90
# 29           51.30          23.0        3.75            18.8          9.94
# 30           55.50          26.9        3.50            18.3          9.30
# 31           52.20          26.3        5.40            18.2         10.20
#
#     Fungicide Price  Herbicide Price  Pesticide Price
# 0              53.3        37.533411       325.207018
# 1              56.0        39.573271       345.388304
# 2              54.6        40.032239       357.497076
# 3              58.0        41.613130       389.787134
# 4              48.5        43.194021       401.319298
# 5              49.6        44.570926       413.428070
# 6              50.6        45.845838       429.573099
# 7              57.4        45.845838       447.447953
# 8              57.8        46.049824       468.205848
# 9              58.5        44.468933       482.044444
# 10             59.4        43.347011       497.036257
# 11             56.1        43.754982       493.000000
# 12             49.7        43.500000       397.000000
# 13             47.2        43.300000       388.000000
# 14             47.4        39.700000       362.000000
# 15             45.2        33.800000       379.000000
# 16             46.7        29.300000       373.000000
# 17             47.0        28.900000       364.000000
# 18             48.2        40.500000       320.000000
# 19             59.8        43.871615       326.000000
# 20             50.0        41.149950       310.000000
# 21             40.8        40.621866       294.000000
# 22             43.8        43.059178       302.000000
# 23             45.3        43.871615       303.000000
# 24             47.2        44.562187       308.000000
# 25             46.3        43.627884       294.537020
# 26             44.4        44.562187       295.910794
# 27             47.3        43.221665       283.272079
# 28             49.3        41.799900       281.074041
# 29             50.3        40.459378       253.323818
# 30             51.3        39.159478       256.071365
# 31             52.3        42.774824       271.182872
#
# [32 rows x 24 columns]

# %% [markdown]
# ### Building Model
#
# Describe your model. Is this Linear Regression or Logistic Regression? Put any other details about the model. Put the codes to build your model.

# %% [raw]
# Our model uses linear regression since we are predicting a quantity(price) instead of a category

# %%
#function used in building linear regression model

def normalize_z(df):
    sd=df.std()
    mean=df.mean()
    df=(df-mean)/sd
    return df
    
    
#get the feature and target columns in format of dataframe
def get_features_targets(df, feature_names, target_names):
    df_feature=pd.DataFrame(df.loc[:,feature_names])
    df_target=pd.DataFrame(df.loc[:,target_names])
    
    return df_feature, df_target

#get feature columns in terms of numpy
def prepare_feature(df_feature):
    ###
    ### YOUR CODE HERE
    ###
    np_feature=df_feature.to_numpy()
    length=df_feature.shape[0]
    
   
    ones=np.ones((length,1),dtype=int)
    
    
    
    returnVal=np.concatenate((ones,np_feature ), axis=1)
    
    return returnVal

#get target column in terms of numpy
def prepare_target(df_target):
    ###
    ### YOUR CODE HERE
    ###
    np_target=df_target.to_numpy()
    
    return np_target

#return single column of predictedy values
def predict(df_feature, beta):
    ###
    ### YOUR CODE HERE
    ###
    df_feature=normalize_z(df_feature)
    np_feature=prepare_feature(df_feature)
    predictedy=calc_linear(np_feature, beta)
    return predictedy

def calc_linear(X, beta):
    ###
    ### YOUR CODE HERE
    ###
    return np.matmul(X,beta)

def split_data(df_feature, df_target, random_state=None, test_size=0.3):
    ###
    ### YOUR CODE HERE
    ###
    testing_size=int(df_feature.shape[0]*test_size)

    
    if random_state!=None:
        np.random.seed(random_state)
    testing_index=np.random.choice(df_feature.index,testing_size,replace=False)

    training_index=set(df_feature.index)-set(testing_index)


    df_feature_train=df_feature.loc[training_index]
    df_feature_test=df_feature.loc[testing_index]
    df_target_test=df_target.loc[testing_index]
    df_target_train=df_target.loc[training_index]

    return df_feature_train, df_feature_test, df_target_train, df_target_test,testing_index
  
def r2_score(y, ypred):
    errorSq=np.matmul((y-ypred).T,(y-ypred))
    SSres=np.sum(errorSq)
    ymean=np.mean(y)
    errorSq=np.matmul((y-ymean).T,(y-ymean))
    SStot=np.sum(errorSq)
    return 1-(SSres/SStot)


def compute_cost(X, y, beta):
   
    m=y.shape[0]
    error=calc_linear(X,beta)-y
    J=(1/(2*m))*np.matmul(error.T,error)
    return J
def gradient_descent(X, y, beta, alpha, num_iters):
    ###
    ### YOUR CODE HERE
    ###
    J_storage=[]
    length=X.shape[0]
    for i in range(num_iters):
        error=calc_linear(X, beta)-y

        beta-=alpha/length*np.matmul(X.T,error)
        J_storage.append(int(compute_cost(X,y,beta)))

    return beta, J_storage

# %%
#putting all the above functions together


def buildModel(df,crop,featuresList,targetStr):
    
    numOfFeatures=len(featuresList)
    df_features, df_target = get_features_targets(df,featuresList,targetStr)
    df_features_train, df_features_test, df_target_train, df_target_test, testing_index = split_data(df_features, df_target,random_state=100,test_size=0.3)

# Normalize the features using z normalization
    df_features_train_z = normalize_z(df_features_train)

# Change the features and the target to numpy array using the prepare functions
    X = prepare_feature(df_features_train_z)
    target = prepare_target(df_target_train)

    iterations = 1500
    alpha = 0.01
    beta = np.zeros((numOfFeatures+1,1))

# Call the gradient_descent function
    beta, J_storage = gradient_descent(X,target,beta,alpha,iterations)

# call the predict() method
    pred = predict(df_features_test,beta)
    
 #data visualization:   
    print("final coefficients respective to order of input",featuresList," are: \n" ,beta, "and final cost is:", J_storage[-1])
    
    plt.scatter(df.loc[list(testing_index),"Year"],df_target_test)
    plt.scatter(df.loc[list(testing_index),"Year"],pred)
    
    
    
    plt.xlabel("Year" )
    plt.ylabel(f"Price of {crop} ")
    plt.legend(["actual price","predicted price"])
    plt.show()

# %%
crops=["Broccoli","Corn","Potato","Cucumber","Carrot"]
for crop in crops:
    buildModel(df=final_df,crop=crop,featuresList=[crop+" Herbicide",crop+" Fungicide", crop+" Pesticide","Herbicide Price","Fungicide Price", "Pesticide Price"],targetStr=crop+" Price")
# Out:
# final coefficients respective to order of input ['Broccoli Herbicide', 'Broccoli Fungicide', 'Broccoli Pesticide', 'Herbicide Price', 'Fungicide Price', 'Pesticide Price']  are:
#  [[33.59346873]
#  [-1.68852863]
#  [-0.72508007]
#  [-9.01495699]
#  [ 0.69906528]
#  [ 0.41893453]
#  [-0.40662996]] and final cost is: 7
# final coefficients respective to order of input ['Corn Herbicide', 'Corn Fungicide', 'Corn Pesticide', 'Herbicide Price', 'Fungicide Price', 'Pesticide Price']  are:
#  [[ 3.38173817]
#  [ 0.12271558]
#  [-0.07433705]
#  [-0.05770853]
#  [ 0.55969917]
#  [-0.43296772]
#  [-0.81001412]] and final cost is: 0
# final coefficients respective to order of input ['Potato Herbicide', 'Potato Fungicide', 'Potato Pesticide', 'Herbicide Price', 'Fungicide Price', 'Pesticide Price']  are:
#  [[ 7.42695442]
#  [ 0.72967292]
#  [-0.12106885]
#  [-1.21397243]
#  [ 0.35371352]
#  [-0.15747927]
#  [-0.51431267]] and final cost is: 0
# final coefficients respective to order of input ['Cucumber Herbicide', 'Cucumber Fungicide', 'Cucumber Pesticide', 'Herbicide Price', 'Fungicide Price', 'Pesticide Price']  are:
#  [[ 2.26173849e+01]
#  [ 1.64122398e-02]
#  [-1.60781603e+00]
#  [ 2.57190916e+00]
#  [-2.27932186e-01]
#  [ 1.15610187e+00]
#  [-2.51602745e+00]] and final cost is: 4
# final coefficients respective to order of input ['Carrot Herbicide', 'Carrot Fungicide', 'Carrot Pesticide', 'Herbicide Price', 'Fungicide Price', 'Pesticide Price']  are:
#  [[21.26086353]
#  [ 0.53543183]
#  [ 2.28101014]
#  [-1.8535601 ]
#  [ 2.04986404]
#  [-2.77568035]
#  [-0.55626881]] and final cost is: 4

# %% [markdown]
# ### Evaluating the Model
#
# Describe your metrics and how you want to evaluate your model. Put any Python code to evaluate your model. Use plots to have a visual evaluation.

# %% [raw]
# Our chosen metrics is adjusted r^2 as adjusted r^2 only increases when the new variable added improves the prediction of the model and decreases when irrelevant variables are added to the model. This is more accurate metric compared to r^2 which increases or remains the same when new variables are added even though these variables might not necessarily improve prediction of model

# %%
# put Python code to evaluate the model and to visualize its accuracy

def adjusted_r2_score(y,ypred,num_indp_var):  
    r2=r2_score(y, ypred)
    sample_size=y.size
    numerator=(1-r2)*(sample_size-1)
    denom=sample_size-num_indp_var-1
    return 1-(numerator/denom)

# %%
#redefine buildModel to display adjusted r2 score

def buildModel(df,crop,featuresList,targetStr):
    
    numOfFeatures=len(featuresList)
    df_features, df_target = get_features_targets(df,featuresList,targetStr)
    df_features_train, df_features_test, df_target_train, df_target_test, testing_index = split_data(df_features, df_target,random_state=100,test_size=0.3)

# Normalize the features using z normalization
    df_features_train_z = normalize_z(df_features_train)

# Change the features and the target to numpy array using the prepare functions
    X = prepare_feature(df_features_train_z)
    target = prepare_target(df_target_train)

    iterations = 1500
    alpha = 0.01
    beta = np.zeros((numOfFeatures+1,1))

# Call the gradient_descent function
    beta, J_storage = gradient_descent(X,target,beta,alpha,iterations)

# call the predict() method
    pred = predict(df_features_test,beta)
    
 #data visualization:   
    print("final coefficients respective to order of input",featuresList," are: \n" ,beta, "and final cost is:", J_storage[-1])
    
    plt.scatter(df.loc[list(testing_index),"Year"],df_target_test)
    plt.scatter(df.loc[list(testing_index),"Year"],pred)
    testTarget=prepare_target(df_target_test)
    
    r2=adjusted_r2_score(testTarget,pred,numOfFeatures)
    plt.xlabel("Year \n adjusted r^2:"+str(r2))
    plt.ylabel(f"Price of {crop} ")
    plt.legend(["actual price","predicted price"])
    plt.show()
    return beta

# %%
#rebuild models now with r^2
crops=["Broccoli","Corn","Potato","Cucumber","Carrot"]
for crop in crops:
    buildModel(final_df,crop,[crop+" Herbicide",crop+" Fungicide", crop+" Pesticide","Herbicide Price","Fungicide Price", "Pesticide Price"],crop+" Price")
    print("\n\n")
# Out:
# final coefficients respective to order of input ['Broccoli Herbicide', 'Broccoli Fungicide', 'Broccoli Pesticide', 'Herbicide Price', 'Fungicide Price', 'Pesticide Price']  are:
#  [[33.59346873]
#  [-1.68852863]
#  [-0.72508007]
#  [-9.01495699]
#  [ 0.69906528]
#  [ 0.41893453]
#  [-0.40662996]] and final cost is: 7
# final coefficients respective to order of input ['Corn Herbicide', 'Corn Fungicide', 'Corn Pesticide', 'Herbicide Price', 'Fungicide Price', 'Pesticide Price']  are:
#  [[ 3.38173817]
#  [ 0.12271558]
#  [-0.07433705]
#  [-0.05770853]
#  [ 0.55969917]
#  [-0.43296772]
#  [-0.81001412]] and final cost is: 0
# final coefficients respective to order of input ['Potato Herbicide', 'Potato Fungicide', 'Potato Pesticide', 'Herbicide Price', 'Fungicide Price', 'Pesticide Price']  are:
#  [[ 7.42695442]
#  [ 0.72967292]
#  [-0.12106885]
#  [-1.21397243]
#  [ 0.35371352]
#  [-0.15747927]
#  [-0.51431267]] and final cost is: 0
# final coefficients respective to order of input ['Cucumber Herbicide', 'Cucumber Fungicide', 'Cucumber Pesticide', 'Herbicide Price', 'Fungicide Price', 'Pesticide Price']  are:
#  [[ 2.26173849e+01]
#  [ 1.64122398e-02]
#  [-1.60781603e+00]
#  [ 2.57190916e+00]
#  [-2.27932186e-01]
#  [ 1.15610187e+00]
#  [-2.51602745e+00]] and final cost is: 4
# final coefficients respective to order of input ['Carrot Herbicide', 'Carrot Fungicide', 'Carrot Pesticide', 'Herbicide Price', 'Fungicide Price', 'Pesticide Price']  are:
#  [[21.26086353]
#  [ 0.53543183]
#  [ 2.28101014]
#  [-1.8535601 ]
#  [ 2.04986404]
#  [-2.77568035]
#  [-0.55626881]] and final cost is: 4

# %% [raw]
# #adjusted r2 is displayed below 'Year' label
#
# out of 5 models , 4 have negative adjusted r^2 which means that not all the independent variables identified actually contribute to the price of crops, thus decreasing accuracy via overparameterization

# %% [markdown]
# ### Improving the Model
#
# Discuss any steps you can do to improve the models. Put any python codes. You can repeat the steps above with the codes to show the improvement in the accuracy.

# %% [markdown]
# # ITERATION 1

# %% [raw]
# We try to find and eliminate variables that does not affect to price of crop by comparing adjusted r^2 values across models fitted with different combinations of independent variables.
#
# If adjusted r^2 values are decrease, it shows that model is less accurate without the removed variables and thus removed variables could be affecting crop price and should be kept.However, if  adjusted r^2 values increase, it shows that model is more accurate without the removed variables and thus removed variables do not affectcrop price and should be discarded
#
# We aim to find the combination of at least 2 independent variables (otherwise it would not be multilinear regression) that produce the largest adjusted r^2

# %%
#for each crop we build the model using different combinations of independent variables and visualize it
for crop in crops:
    print(f"----------------------------------------------------{crop}----------------------------------------------------")
    buildModel(final_df,crop,[crop+" Herbicide",crop+" Fungicide", crop+" Pesticide"],crop+" Price")#remove all prices of chemicals
    buildModel(final_df,crop,["Herbicide Price","Fungicide Price", "Pesticide Price"],crop+" Price")#remove all amnts of chemicals
    buildModel(final_df,crop,[crop+" Herbicide",crop+" Fungicide"],crop+" Price")#remove all prices and pesticide
    buildModel(final_df,crop,[crop+" Herbicide", crop+" Pesticide"],crop+" Price")#remove all prices and fungicide
    buildModel(final_df,crop,[crop+" Fungicide", crop+" Pesticide"],crop+" Price")#remove all prices and herbicide
    buildModel(final_df,crop,[crop+" Herbicide", crop+" Pesticide","Herbicide Price", "Pesticide Price"],crop+" Price")#remove fungicide amnt and price
    buildModel(final_df,crop,[crop+" Herbicide", crop+" Fungicide","Herbicide Price","Fungicide Price"],crop+" Price")#remove pesticide amnt and price
    buildModel(final_df,crop,[crop+" Pesticide", crop+" Fungicide","Pesticide Price","Fungicide Price"],crop+" Price")#remove herbicide amnt and price
    print("\n\n\n\n\n")
# Out:
# ----------------------------------------------------Broccoli----------------------------------------------------
# final coefficients respective to order of input ['Broccoli Herbicide', 'Broccoli Fungicide', 'Broccoli Pesticide']  are:
#  [[33.59346873]
#  [-1.55375656]
#  [-0.29482928]
#  [-9.00098628]] and final cost is: 7
# final coefficients respective to order of input ['Herbicide Price', 'Fungicide Price', 'Pesticide Price']  are:
#  [[33.59346873]
#  [ 2.46347873]
#  [ 0.10247782]
#  [-7.2550431 ]] and final cost is: 26
# final coefficients respective to order of input ['Broccoli Herbicide', 'Broccoli Fungicide']  are:
#  [[33.59346873]
#  [-3.61601716]
#  [ 4.750901  ]] and final cost is: 29
# final coefficients respective to order of input ['Broccoli Herbicide', 'Broccoli Pesticide']  are:
#  [[33.59346873]
#  [-1.52989143]
#  [-8.83439949]] and final cost is: 7
# final coefficients respective to order of input ['Broccoli Fungicide', 'Broccoli Pesticide']  are:
#  [[33.59346873]
#  [-0.1693415 ]
#  [-9.54050002]] and final cost is: 8
# final coefficients respective to order of input ['Broccoli Herbicide', 'Broccoli Pesticide', 'Herbicide Price', 'Pesticide Price']  are:
#  [[33.59346873]
#  [-1.66349671]
#  [-8.764779  ]
#  [ 0.52479597]
#  [ 0.0947277 ]] and final cost is: 7
# final coefficients respective to order of input ['Broccoli Herbicide', 'Broccoli Fungicide', 'Herbicide Price', 'Fungicide Price']  are:
#  [[33.59346873]
#  [-3.61984782]
#  [ 3.86439662]
#  [ 1.02507767]
#  [-2.28786811]] and final cost is: 27
# final coefficients respective to order of input ['Broccoli Pesticide', 'Broccoli Fungicide', 'Pesticide Price', 'Fungicide Price']  are:
#  [[33.59346873]
#  [-9.58265184]
#  [-0.2591321 ]
#  [-0.40505243]
#  [ 0.72132116]] and final cost is: 8
# ----------------------------------------------------Corn----------------------------------------------------
# final coefficients respective to order of input ['Corn Herbicide', 'Corn Fungicide', 'Corn Pesticide']  are:
#  [[ 3.38173817]
#  [ 0.55107747]
#  [-0.09265381]
#  [-0.70207251]] and final cost is: 0
# final coefficients respective to order of input ['Herbicide Price', 'Fungicide Price', 'Pesticide Price']  are:
#  [[ 3.38173817]
#  [ 0.5559443 ]
#  [-0.39828486]
#  [-0.89195842]] and final cost is: 0
# final coefficients respective to order of input ['Corn Herbicide', 'Corn Fungicide']  are:
#  [[3.38173817]
#  [0.15045308]
#  [0.55215759]] and final cost is: 0
# final coefficients respective to order of input ['Corn Herbicide', 'Corn Pesticide']  are:
#  [[ 3.38173817]
#  [ 0.49565549]
#  [-0.66222667]] and final cost is: 0
# final coefficients respective to order of input ['Corn Fungicide', 'Corn Pesticide']  are:
#  [[ 3.38173817]
#  [ 0.40483849]
#  [-0.48216425]] and final cost is: 0
# final coefficients respective to order of input ['Corn Herbicide', 'Corn Pesticide', 'Herbicide Price', 'Pesticide Price']  are:
#  [[ 3.38173817]
#  [-0.1213753 ]
#  [-0.11771141]
#  [ 0.45434667]
#  [-1.11924142]] and final cost is: 0
# final coefficients respective to order of input ['Corn Herbicide', 'Corn Fungicide', 'Herbicide Price', 'Fungicide Price']  are:
#  [[ 3.38173817]
#  [ 0.44540131]
#  [ 0.15922974]
#  [ 0.58230211]
#  [-0.91565282]] and final cost is: 0
# final coefficients respective to order of input ['Corn Pesticide', 'Corn Fungicide', 'Pesticide Price', 'Fungicide Price']  are:
#  [[ 3.38173817e+00]
#  [-1.59564296e-01]
#  [ 2.94830697e-03]
#  [-8.48754823e-01]
#  [-1.42400463e-01]] and final cost is: 0
# ----------------------------------------------------Potato----------------------------------------------------
# final coefficients respective to order of input ['Potato Herbicide', 'Potato Fungicide', 'Potato Pesticide']  are:
#  [[ 7.42695442]
#  [ 1.14526509]
#  [-0.19903578]
#  [-1.71656631]] and final cost is: 0
# final coefficients respective to order of input ['Herbicide Price', 'Fungicide Price', 'Pesticide Price']  are:
#  [[ 7.42695442]
#  [ 0.36034942]
#  [-0.27984897]
#  [-1.26655318]] and final cost is: 0
# final coefficients respective to order of input ['Potato Herbicide', 'Potato Fungicide']  are:
#  [[7.42695442]
#  [0.24772173]
#  [0.55527593]] and final cost is: 1
# final coefficients respective to order of input ['Potato Herbicide', 'Potato Pesticide']  are:
#  [[ 7.42695442]
#  [ 1.05778426]
#  [-1.62209913]] and final cost is: 0
# final coefficients respective to order of input ['Potato Fungicide', 'Potato Pesticide']  are:
#  [[ 7.42695442]
#  [ 0.28138041]
#  [-1.10050501]] and final cost is: 0
# final coefficients respective to order of input ['Potato Herbicide', 'Potato Pesticide', 'Herbicide Price', 'Pesticide Price']  are:
#  [[ 7.42695442]
#  [ 0.6850857 ]
#  [-1.18674649]
#  [ 0.29434691]
#  [-0.59619345]] and final cost is: 0
# final coefficients respective to order of input ['Potato Herbicide', 'Potato Fungicide', 'Herbicide Price', 'Fungicide Price']  are:
#  [[ 7.42695442]
#  [ 0.20129752]
#  [ 0.29200701]
#  [ 0.33277764]
#  [-0.93499021]] and final cost is: 0
# final coefficients respective to order of input ['Potato Pesticide', 'Potato Fungicide', 'Pesticide Price', 'Fungicide Price']  are:
#  [[ 7.42695442e+00]
#  [-6.18285479e-01]
#  [ 2.20407224e-01]
#  [-1.01570596e+00]
#  [-3.74813295e-03]] and final cost is: 0
# ----------------------------------------------------Cucumber----------------------------------------------------
# final coefficients respective to order of input ['Cucumber Herbicide', 'Cucumber Fungicide', 'Cucumber Pesticide']  are:
#  [[22.61738489]
#  [ 0.83152294]
#  [-0.56964649]
#  [ 2.65499487]] and final cost is: 5
# final coefficients respective to order of input ['Herbicide Price', 'Fungicide Price', 'Pesticide Price']  are:
#  [[22.61738489]
#  [-1.18242736]
#  [ 0.31693434]
#  [-0.4322965 ]] and final cost is: 7
# final coefficients respective to order of input ['Cucumber Herbicide', 'Cucumber Fungicide']  are:
#  [[22.61738489]
#  [-1.16445822]
#  [ 0.12902111]] and final cost is: 7
# final coefficients respective to order of input ['Cucumber Herbicide', 'Cucumber Pesticide']  are:
#  [[22.61738489]
#  [ 0.50374516]
#  [ 2.43110347]] and final cost is: 5
# final coefficients respective to order of input ['Cucumber Fungicide', 'Cucumber Pesticide']  are:
#  [[22.61738489]
#  [-0.29293392]
#  [ 2.10335948]] and final cost is: 5
# final coefficients respective to order of input ['Cucumber Herbicide', 'Cucumber Pesticide', 'Herbicide Price', 'Pesticide Price']  are:
#  [[22.61738489]
#  [ 0.0658871 ]
#  [ 2.03558778]
#  [-0.36124117]
#  [-0.48533776]] and final cost is: 5
# final coefficients respective to order of input ['Cucumber Herbicide', 'Cucumber Fungicide', 'Herbicide Price', 'Fungicide Price']  are:
#  [[22.61738489]
#  [-1.16918557]
#  [ 0.30723141]
#  [-1.18551172]
#  [ 0.34439857]] and final cost is: 6
# final coefficients respective to order of input ['Cucumber Pesticide', 'Cucumber Fungicide', 'Pesticide Price', 'Fungicide Price']  are:
#  [[22.61738489]
#  [ 2.63295141]
#  [-1.75965434]
#  [-2.64807548]
#  [ 1.08041036]] and final cost is: 4
# ----------------------------------------------------Carrot----------------------------------------------------
# final coefficients respective to order of input ['Carrot Herbicide', 'Carrot Fungicide', 'Carrot Pesticide']  are:
#  [[21.26086353]
#  [ 0.07910817]
#  [ 2.6530158 ]
#  [-2.70766262]] and final cost is: 8
# final coefficients respective to order of input ['Herbicide Price', 'Fungicide Price', 'Pesticide Price']  are:
#  [[21.26086353]
#  [ 1.32055294]
#  [-2.55550014]
#  [-3.13635682]] and final cost is: 6
# final coefficients respective to order of input ['Carrot Herbicide', 'Carrot Fungicide']  are:
#  [[21.26086353]
#  [-1.39764759]
#  [ 3.66099672]] and final cost is: 9
# final coefficients respective to order of input ['Carrot Herbicide', 'Carrot Pesticide']  are:
#  [[21.26086353]
#  [ 0.71777464]
#  [-4.17422606]] and final cost is: 10
# final coefficients respective to order of input ['Carrot Fungicide', 'Carrot Pesticide']  are:
#  [[21.26086353]
#  [ 2.66596558]
#  [-2.65902528]] and final cost is: 8
# final coefficients respective to order of input ['Carrot Herbicide', 'Carrot Pesticide', 'Herbicide Price', 'Pesticide Price']  are:
#  [[21.26086353]
#  [ 0.58716127]
#  [-2.16703633]
#  [ 0.88614512]
#  [-3.47435826]] and final cost is: 6
# final coefficients respective to order of input ['Carrot Herbicide', 'Carrot Fungicide', 'Herbicide Price', 'Fungicide Price']  are:
#  [[21.26086353]
#  [-0.44991358]
#  [ 3.2569942 ]
#  [ 2.26181086]
#  [-3.33784205]] and final cost is: 5
# final coefficients respective to order of input ['Carrot Pesticide', 'Carrot Fungicide', 'Pesticide Price', 'Fungicide Price']  are:
#  [[21.26086353]
#  [-1.31829266]
#  [ 1.4593625 ]
#  [-1.40482747]
#  [-1.90729513]] and final cost is: 6

# %% [raw]
# #findings summary:
#
# best adjusted r^2 for each crop and the relevant combination of independent variable
#
# Broccoli-> 0.37652 only prices of all 3 types of chemicals, a significant improvement from the previos -5.08
# Corn -> -1.0562 only herbicide and fungicide quantity,  significant improvement from the previous -10.059
# Potato-> 0.743 only herbicide and pesticide quantity, an improvement from previous 0.2480
# Cucumber->0.5354 only herbicide and pesticide quantity, a significant improvement from the previous -1.183
# Carrot-> -0.105708 only herbicide and pesticide quantity,a significant improvement from the previous -1.6856
#
# For all crops, improvement in prediction can be seen and for each of the crops, the irrelevant variables are different since the combinations of independent variable that produce the best adjusted r^2 for each crop is different
#
# Despite the improvements out of 5 crops, predictions for Corn and Carrot are very poor with negative and broccoli is mediocre at 0.376.This could be due to the accuracy of data which we filled in manually
#
# Alternatively, we felt that maybe our initial hypothesis when constructing our problem statement might not be fully true and there could be other more significant factors like consumer demand or operation cost that is actually affecting the prices which we did not consider.

# %% [markdown]
# # ITERATION 2

# %% [raw]
# We decided to build on our previous iteration by introducing 3 more new independent variables:
# -global population( in thousands) -> may affect overseas consumer demand of crops exported from US
# -operational cost of agriculture across US ($USD) -> affect cost of production which carry on to consumers
# -consumption (for each type of crop) per capita in US (lb)->may affect local consumer demand
#
# data cleaning will be similar to what is done above

# %%
def getColumns_consumptionExcel(filename):
    df=pd.read_excel(filename,sheet_name="Data")
    newName=filename[:-5]# this is to rename the'value' column to file name, fileename is set as column name for convenience
    df=df.rename(columns={"Unnamed: 1":"Year","Unnamed: 2":newName})
    df=df.iloc[4:,1:]
    display(df)
    return df

# %%
corn_consumption_df=getColumns_consumptionExcel("Corn consumption per capita.xlsx")
broccoli_consumption_df=getColumns_consumptionExcel("Broccoli consumption per capita.xlsx")
carrot_consumption_df=getColumns_consumptionExcel("Carrot consumption per capita.xlsx")
potato_consumption_df=getColumns_consumptionExcel("Potato consumption per capita.xlsx")
cucumber_consumption_df=getColumns_consumptionExcel("Cucumber consumption per capita.xlsx")

operating_cost_df=getColumns("US annual agriculture operation costs.csv",["Year","Value"])
display(operating_cost_df)

world_pop_df=pd.read_excel("world population.xlsx")
world_pop_df=world_pop_df.iloc[56:88,10:12]
world_pop_df=world_pop_df.rename(columns={"Unnamed: 10":"Year", "Unnamed: 11":"World Population as of 1 Jan in Thousands"})
display(world_pop_df)
# Out:
#     Year  Corn consumption per capita
# 4   2000                         28.4
# 5   2001                         29.0
# 6   2002                         29.7
# 7   2003                         30.3
# 8   2004                         30.9
# 9   2005                         31.4
# 10  2006                         31.9
# 11  2007                         32.4
# 12  2008                         33.0
# 13  2009                         33.0
# 14  2010                         33.1
# 15  2011                         34.1
# 16  2012                         33.9
# 17  2013                         33.9
# 18  2014                         34.0
# 19  2015                         34.0
# 20  2016                         34.2
# 21  2017                         34.6
# 22  2018                         34.9
# 23  2019                         36.5
#     Year  Broccoli consumption per capita
# 4   2000                              5.9
# 5   2001                              5.4
# 6   2002                              5.4
# 7   2003                              5.3
# 8   2004                              5.3
# 9   2005                              5.3
# 10  2006                              5.8
# 11  2007                              5.6
# 12  2008                              6.0
# 13  2009                              6.2
# 14  2010                              5.6
# 15  2011                              5.9
# 16  2012                              6.3
# 17  2013                              6.9
# 18  2014                              6.6
# 19  2015                              7.4
# 20  2016                              7.5
# 21  2017                              7.1
# 22  2018                              5.9
# 23  2019                              5.9
# 24  2020                              5.9
# 25  2021                              5.2
#     Year  Carrot consumption per capita
# 4   2000                            9.2
# 5   2001                            9.4
# 6   2002                            8.4
# 7   2003                            8.8
# 8   2004                            8.7
# 9   2005                            8.7
# 10  2006                            8.1
# 11  2007                            8.0
# 12  2008                            8.1
# 13  2009                            7.4
# 14  2010                            7.8
# 15  2011                            7.5
# 16  2012                            7.9
# 17  2013                            8.0
# 18  2014                            8.5
# 19  2015                            8.8
# 20  2016                            7.8
# 21  2017                            7.4
# 22  2018                           12.2
# 23  2019                            8.5
# 24  2020                            8.3
# 25  2021                            8.6
#     Year  Potato consumption per capita
# 4   2000                           47.1
# 5   2001                           46.6
# 6   2002                           44.3
# 7   2003                           46.8
# 8   2004                           45.8
# 9   2005                           41.3
# 10  2006                           38.6
# 11  2007                           38.7
# 12  2008                           37.8
# 13  2009                           36.6
# 14  2010                           36.8
# 15  2011                           34.0
# 16  2012                           34.5
# 17  2013                           34.5
# 18  2014                           33.6
# 19  2015                           34.2
# 20  2016                           33.7
# 21  2017                           34.9
# 22  2018                           33.1
# 23  2019                           30.1
# 24  2020                           30.3
# 25  2021                           29.3
#     Year  Cucumber consumption per capita
# 4   2000                              6.4
# 5   2001                              6.3
# 6   2002                              6.6
# 7   2003                              6.2
# 8   2004                              6.4
# 9   2005                              6.2
# 10  2006                              6.1
# 11  2007                              6.4
# 12  2008                              6.4
# 13  2009                              6.8
# 14  2010                              6.7
# 15  2011                              6.4
# 16  2012                              7.1
# 17  2013                              7.3
# 18  2014                              7.4
# 19  2015                              7.5
# 20  2016                              8.1
# 21  2017                              7.4
# 22  2018                              8.0
# 23  2019                              7.8
# 24  2020                              7.5
# 25  2021                              8.0
#     Year US annual agriculture operation costs
# 0   2020                       366,200,000,000
# 1   2019                       357,800,000,000
# 2   2018                       354,000,000,000
# 3   2017                       357,800,000,000
# 4   2016                       346,900,000,000
# 5   2015                       362,800,000,000
# 6   2014                       397,600,000,000
# 7   2013                       367,270,000,000
# 8   2012                       360,100,000,000
# 9   2011                       318,650,000,000
# 10  2010                       289,050,000,000
# 11  2009                       287,400,000,000
# 12  2008                       307,020,000,000
# 13  2007                       283,520,000,000
# 14  2006                       237,810,000,000
# 15  2005                       222,940,000,000
# 16  2004                       211,800,000,000
# 17  2003                       200,500,000,000
# 18  2002                       193,100,000,000
# 19  2001                       195,200,000,000
# 20  2000                       189,600,000,000
# 21  1999                       184,050,000,000
# 22  1998                       183,150,000,000
# 23  1997                       183,180,000,000
# 24  1996                       174,950,000,000
# 25  1995                       167,800,000,000
# 26  1994                       160,670,000,000
# 27  1993                       155,160,000,000
# 28  1992                       144,800,000,000
# 29  1991                       147,170,000,000
# 30  1990                       131,554,000,000
#     Year World Population as of 1 Jan in Thousands
# 56  1990                               5269760.352
# 57  1991                               5362591.372
# 58  1992                               5449900.363
# 59  1993                               5535471.822
# 60  1994                               5619395.224
# 61  1995                               5702060.762
# 62  1996                               5784378.146
# 63  1997                                5865912.45
# 64  1998                               5947050.072
# 65  1999                               6027574.888
# 66  2000                               6107942.028
# 67  2001                               6189855.922
# 68  2002                               6271638.043
# 69  2003                               6353176.677
# 70  2004                               6434620.053
# 71  2005                               6516882.903
# 72  2006                               6599469.335
# 73  2007                               6683363.101
# 74  2008                               6768533.988
# 75  2009                               6854660.556
# 76  2010                                6941951.26
# 77  2011                                7029254.95
# 78  2012                                 7116995.9
# 79  2013                               7206399.942
# 80  2014                               7294786.798
# 81  2015                                7383240.04
# 82  2016                               7469955.033
# 83  2017                               7556993.443
# 84  2018                               7642651.364
# 85  2019                               7724928.292
# 86  2020                               7804973.773
# 87  2021                               7876931.987

# %%
#cleaning and merging with old dataframe
listOfNewdf=[
    corn_consumption_df,
    broccoli_consumption_df,
    carrot_consumption_df,
    potato_consumption_df,
    cucumber_consumption_df,
    operating_cost_df,
    world_pop_df
    
    
    
]

improved_df=final_df
for df in listOfNewdf:
    df=cleanData(df)
    improved_df=improved_df.merge(df, how='outer', on='Year')

display(improved_df)
# Out:
#     Year  Broccoli Fungicide  Broccoli Herbicide  Broccoli Pesticide  \
# 0   1990               28300              213000              263100
# 1   1991               28300              214000              263100
# 2   1992               28300              214000              263100
# 3   1993               37700              150300              270300
# 4   1994               47500              242100              286900
# 5   1995               43300              220300              150300
# 6   1996               43300              201400              260200
# 7   1997               35300              180500              196300
# 8   1998               36700              177400              176800
# 9   1999               30500              232500              214500
# 10  2000               25900              234300              270100
# 11  2001               20300              200500              240300
# 12  2002               15400              148900              234800
# 13  2003               20000              120500              220500
# 14  2004               19300              115800              239500
# 15  2005               17300              134500              190500
# 16  2006               15300              218900              180500
# 17  2007               16300              220500              170500
# 18  2008               20400              345600              150300
# 19  2009               25300              254300              135200
# 20  2010               40700              133000              121300
# 21  2011               45300              200000              120300
# 22  2012               46300              210000              119400
# 23  2013               47500              234000              100500
# 24  2014               48500              228400              120500
# 25  2015               32500              150300               90300
# 26  2016               37400              135100              696900
# 27  2017               70500              123300               90300
# 28  2018               89100              110300              101300
# 29  2019               65300               95300               98300
# 30  2020               59900               83400               50800
# 31  2021               60300               75300               51800
#
#     Carrot Fungicide  Carrot Herbicide  Carrot Pesticide  Corn Fungicide  \
# 0             687000             89200             42000           20000
# 1             687000             89100             42000           15000
# 2             687000             89100             42000           18000
# 3             500400            100000             58300           12000
# 4             483400            117700             57700           16000
# 5             473300            160700             54900           17000
# 6             469100            153200             55900           17000
# 7             470300            160300             57300           14000
# 8             508300            154300             60400           15000
# 9             400500             90300             40300           18000
# 10            220000             88300             21000           17000
# 11            230300             90200             27000           50000
# 12            135900             90700             28000          120000
# 13            170300             75300             20000          232000
# 14            201400             51100             19000          200000
# 15            700300             90000             16000           93000
# 16           1051300             86600             15000          167000
# 17           1023300             78800             18000          185000
# 18            900600             79900             19000          300000
# 19            920300             80000             20000          452000
# 20            897300             87300             21000          744000
# 21            863500             89300             22000          852000
# 22            896500             86300             19000          912000
# 23            753800             70300             15000         1007000
# 24            895300             57300             12000         1162000
# 25            680300             60300              8000         1200000
# 26            687300             78300              7000         1329000
# 27            650600             79300              2000         1300000
# 28            671600             57300              4000         3775000
# 29            700400             80400              4000         3000000
# 30            893200            116600              4000         4562000
# 31            900500            120000              4000         4200000
#
#     Corn Herbicide  Corn Pesticide  ...  Fungicide Price  Herbicide Price  \
# 0        207850000        21309000  ...             53.3        37.533411
# 1        189469000        20932000  ...             56.0        39.573271
# 2        199084000        18402000  ...             54.6        40.032239
# 3        181876000        16638000  ...             58.0        41.613130
# 4        170221000        13695000  ...             48.5        43.194021
# 5        167642000        13457000  ...             49.6        44.570926
# 6        186977000        14218000  ...             50.6        45.845838
# 7        164051000        13570000  ...             57.4        45.845838
# 8        177012000        12118000  ...             57.8        46.049824
# 9        154059000        10115000  ...             58.5        44.468933
# 10       153464000         9811000  ...             59.4        43.347011
# 11       157239000         9004000  ...             56.1        43.754982
# 12        95777000         3931000  ...             49.7        43.500000
# 13       149136000         7465000  ...             47.2        43.300000
# 14       135755000         5786000  ...             47.4        39.700000
# 15       157575000         4849000  ...             45.2        33.800000
# 16       164875000         3897000  ...             46.7        29.300000
# 17       165743000         3765000  ...             47.0        28.900000
# 18       175583000         2785000  ...             48.2        40.500000
# 19       181520000         2935000  ...             59.8        43.871615
# 20       182150000         1631000  ...             50.0        41.149950
# 21       173854000         1620000  ...             40.8        40.621866
# 22       173896000         1615000  ...             43.8        43.059178
# 23       175394000         1607000  ...             45.3        43.871615
# 24       176291000         1684000  ...             47.2        44.562187
# 25       208953000         1894000  ...             46.3        43.627884
# 26       226042000         1922000  ...             44.4        44.562187
# 27       215786000         2000000  ...             47.3        43.221665
# 28       214721000         2087000  ...             49.3        41.799900
# 29       257893000         1597000  ...             50.3        40.459378
# 30       247893000         1298000  ...             51.3        39.159478
# 31       237818000         1099000  ...             52.3        42.774824
#
#     Pesticide Price  Corn consumption per capita  \
# 0        325.207018                          NaN
# 1        345.388304                          NaN
# 2        357.497076                          NaN
# 3        389.787134                          NaN
# 4        401.319298                          NaN
# 5        413.428070                          NaN
# 6        429.573099                          NaN
# 7        447.447953                          NaN
# 8        468.205848                          NaN
# 9        482.044444                          NaN
# 10       497.036257                         28.4
# 11       493.000000                         29.0
# 12       397.000000                         29.7
# 13       388.000000                         30.3
# 14       362.000000                         30.9
# 15       379.000000                         31.4
# 16       373.000000                         31.9
# 17       364.000000                         32.4
# 18       320.000000                         33.0
# 19       326.000000                         33.0
# 20       310.000000                         33.1
# 21       294.000000                         34.1
# 22       302.000000                         33.9
# 23       303.000000                         33.9
# 24       308.000000                         34.0
# 25       294.537020                         34.0
# 26       295.910794                         34.2
# 27       283.272079                         34.6
# 28       281.074041                         34.9
# 29       253.323818                         36.5
# 30       256.071365                          NaN
# 31       271.182872                          NaN
#
#     Broccoli consumption per capita  Carrot consumption per capita  \
# 0                               NaN                            NaN
# 1                               NaN                            NaN
# 2                               NaN                            NaN
# 3                               NaN                            NaN
# 4                               NaN                            NaN
# 5                               NaN                            NaN
# 6                               NaN                            NaN
# 7                               NaN                            NaN
# 8                               NaN                            NaN
# 9                               NaN                            NaN
# 10                              5.9                            9.2
# 11                              5.4                            9.4
# 12                              5.4                            8.4
# 13                              5.3                            8.8
# 14                              5.3                            8.7
# 15                              5.3                            8.7
# 16                              5.8                            8.1
# 17                              5.6                            8.0
# 18                              6.0                            8.1
# 19                              6.2                            7.4
# 20                              5.6                            7.8
# 21                              5.9                            7.5
# 22                              6.3                            7.9
# 23                              6.9                            8.0
# 24                              6.6                            8.5
# 25                              7.4                            8.8
# 26                              7.5                            7.8
# 27                              7.1                            7.4
# 28                              5.9                           12.2
# 29                              5.9                            8.5
# 30                              5.9                            8.3
# 31                              5.2                            8.6
#
#     Potato consumption per capita  Cucumber consumption per capita  \
# 0                             NaN                              NaN
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# 5                             NaN                              NaN
# 6                             NaN                              NaN
# 7                             NaN                              NaN
# 8                             NaN                              NaN
# 9                             NaN                              NaN
# 10                           47.1                              6.4
# 11                           46.6                              6.3
# 12                           44.3                              6.6
# 13                           46.8                              6.2
# 14                           45.8                              6.4
# 15                           41.3                              6.2
# 16                           38.6                              6.1
# 17                           38.7                              6.4
# 18                           37.8                              6.4
# 19                           36.6                              6.8
# 20                           36.8                              6.7
# 21                           34.0                              6.4
# 22                           34.5                              7.1
# 23                           34.5                              7.3
# 24                           33.6                              7.4
# 25                           34.2                              7.5
# 26                           33.7                              8.1
# 27                           34.9                              7.4
# 28                           33.1                              8.0
# 29                           30.1                              7.8
# 30                           30.3                              7.5
# 31                           29.3                              8.0
#
#     US annual agriculture operation costs  \
# 0                            1.315540e+11
# 1                            1.471700e+11
# 2                            1.448000e+11
# 3                            1.551600e+11
# 4                            1.606700e+11
# 5                            1.678000e+11
# 6                            1.749500e+11
# 7                            1.831800e+11
# 8                            1.831500e+11
# 9                            1.840500e+11
# 10                           1.896000e+11
# 11                           1.952000e+11
# 12                           1.931000e+11
# 13                           2.005000e+11
# 14                           2.118000e+11
# 15                           2.229400e+11
# 16                           2.378100e+11
# 17                           2.835200e+11
# 18                           3.070200e+11
# 19                           2.874000e+11
# 20                           2.890500e+11
# 21                           3.186500e+11
# 22                           3.601000e+11
# 23                           3.672700e+11
# 24                           3.976000e+11
# 25                           3.628000e+11
# 26                           3.469000e+11
# 27                           3.578000e+11
# 28                           3.540000e+11
# 29                           3.578000e+11
# 30                           3.662000e+11
# 31                                    NaN
#
#     World Population as of 1 Jan in Thousands
# 0                                 5269760.352
# 1                                 5362591.372
# 2                                 5449900.363
# 3                                 5535471.822
# 4                                 5619395.224
# 5                                 5702060.762
# 6                                 5784378.146
# 7                                 5865912.450
# 8                                 5947050.072
# 9                                 6027574.888
# 10                                6107942.028
# 11                                6189855.922
# 12                                6271638.043
# 13                                6353176.677
# 14                                6434620.053
# 15                                6516882.903
# 16                                6599469.335
# 17                                6683363.101
# 18                                6768533.988
# 19                                6854660.556
# 20                                6941951.260
# 21                                7029254.950
# 22                                7116995.900
# 23                                7206399.942
# 24                                7294786.798
# 25                                7383240.040
# 26                                7469955.033
# 27                                7556993.443
# 28                                7642651.364
# 29                                7724928.292
# 30                                7804973.773
# 31                                7876931.987
#
# [32 rows x 31 columns]

# %%
#improved_df.to_excel("improvedTable(2).xlsx")   -> again to fill in missing values we couldn't find
improved_final_df=pd.read_excel("improvedTable(2).xlsx").iloc[:,1:] #iloc to remove unnamed column
display(improved_final_df)
# Out:
#     Year  Broccoli Fungicide  Broccoli Herbicide  Broccoli Pesticide  \
# 0   1990               28300              213000              263100
# 1   1991               28300              214000              263100
# 2   1992               28300              214000              263100
# 3   1993               37700              150300              270300
# 4   1994               47500              242100              286900
# 5   1995               43300              220300              150300
# 6   1996               43300              201400              260200
# 7   1997               35300              180500              196300
# 8   1998               36700              177400              176800
# 9   1999               30500              232500              214500
# 10  2000               25900              234300              270100
# 11  2001               20300              200500              240300
# 12  2002               15400              148900              234800
# 13  2003               20000              120500              220500
# 14  2004               19300              115800              239500
# 15  2005               17300              134500              190500
# 16  2006               15300              218900              180500
# 17  2007               16300              220500              170500
# 18  2008               20400              345600              150300
# 19  2009               25300              254300              135200
# 20  2010               40700              133000              121300
# 21  2011               45300              200000              120300
# 22  2012               46300              210000              119400
# 23  2013               47500              234000              100500
# 24  2014               48500              228400              120500
# 25  2015               32500              150300               90300
# 26  2016               37400              135100              696900
# 27  2017               70500              123300               90300
# 28  2018               89100              110300              101300
# 29  2019               65300               95300               98300
# 30  2020               59900               83400               50800
# 31  2021               60300               75300               51800
#
#     Carrot Fungicide  Carrot Herbicide  Carrot Pesticide  Corn Fungicide  \
# 0             687000             89200             42000           20000
# 1             687000             89100             42000           15000
# 2             687000             89100             42000           18000
# 3             500400            100000             58300           12000
# 4             483400            117700             57700           16000
# 5             473300            160700             54900           17000
# 6             469100            153200             55900           17000
# 7             470300            160300             57300           14000
# 8             508300            154300             60400           15000
# 9             400500             90300             40300           18000
# 10            220000             88300             21000           17000
# 11            230300             90200             27000           50000
# 12            135900             90700             28000          120000
# 13            170300             75300             20000          232000
# 14            201400             51100             19000          200000
# 15            700300             90000             16000           93000
# 16           1051300             86600             15000          167000
# 17           1023300             78800             18000          185000
# 18            900600             79900             19000          300000
# 19            920300             80000             20000          452000
# 20            897300             87300             21000          744000
# 21            863500             89300             22000          852000
# 22            896500             86300             19000          912000
# 23            753800             70300             15000         1007000
# 24            895300             57300             12000         1162000
# 25            680300             60300              8000         1200000
# 26            687300             78300              7000         1329000
# 27            650600             79300              2000         1300000
# 28            671600             57300              4000         3775000
# 29            700400             80400              4000         3000000
# 30            893200            116600              4000         4562000
# 31            900500            120000              4000         4200000
#
#     Corn Herbicide  Corn Pesticide  ...  Total Fungicide  Total Herbicide  \
# 0        207850000        21309000  ...          1626500        210148400
# 1        189469000        20932000  ...          3490500        191862300
# 2        199084000        18402000  ...          3896500        201143300
# 3        181876000        16638000  ...          4203100        184080500
# 4        170221000        13695000  ...          5981300        172916400
# 5        167642000        13457000  ...          7400100        170499500
# 6        186977000        14218000  ...          4755500        189086800
# 7        164051000        13570000  ...          8175200        166088100
# 8        177012000        12118000  ...          1945700        177500000
# 9        154059000        10115000  ...          7806500        156464100
# 10       153464000         9811000  ...          6753100        155275400
# 11       157239000         9004000  ...          5736000        158921200
# 12        95777000         3931000  ...          7302500         97346100
# 13       149136000         7465000  ...          7210600        150937100
# 14       135755000         5786000  ...          9434900        137234500
# 15       157575000         4849000  ...          6701300        159223300
# 16       164875000         3897000  ...          7028700        166871300
# 17       165743000         3765000  ...          7091600        167732100
# 18       175583000         2785000  ...          7133300        177710700
# 19       181520000         2935000  ...          7914900        183557500
# 20       182150000         1631000  ...          7549000        184099600
# 21       173854000         1620000  ...          8143800        175871800
# 22       173896000         1615000  ...          8604800        175918600
# 23       175394000         1607000  ...          8504300        177384500
# 24       176291000         1684000  ...          8657100        178294000
# 25       208953000         1894000  ...          9158200        210984900
# 26       226042000         1922000  ...          9597000        228159700
# 27       215786000         2000000  ...          9551400        218000900
# 28       214721000         2087000  ...         12217200        216895700
# 29       257893000         1597000  ...         12019200        260041000
# 30       247893000         1298000  ...         13985400        249947800
# 31       237818000         1099000  ...         13831100        240006730
#
#     Total Pesticide  Corn consumption per capita  \
# 0          24433900                         26.0
# 1          24195900                         26.6
# 2          21584900                         27.0
# 3          20067900                         27.2
# 4          17721500                         27.4
# 5          16302500                         27.6
# 6          15978300                         28.0
# 7          16160900                         28.2
# 8          12540100                         28.3
# 9          13006100                         28.4
# 10         12159800                         28.4
# 11         11183300                         29.0
# 12          6033800                         29.7
# 13          9344800                         30.3
# 14          7313900                         30.9
# 15          6118800                         31.4
# 16          4928200                         31.9
# 17          4783800                         32.4
# 18          3674600                         33.0
# 19          3915500                         33.0
# 20          2583600                         33.1
# 21          2574700                         34.1
# 22          2662400                         33.9
# 23          2659500                         33.9
# 24          2768500                         34.0
# 25          2729300                         34.0
# 26          3079100                         34.2
# 27          2548600                         34.6
# 28          2648900                         34.9
# 29          2320600                         36.5
# 30          1852400                         36.0
# 31          1662800                         36.3
#
#     Broccoli consumption per capita  Carrot consumption per capita  \
# 0                               5.1                            8.8
# 1                               5.0                            8.6
# 2                               5.2                            8.6
# 3                               5.4                            8.7
# 4                               5.3                            8.9
# 5                               5.5                            9.2
# 6                               5.6                            9.0
# 7                               5.6                            9.1
# 8                               5.6                            9.2
# 9                               5.7                            9.1
# 10                              5.9                            9.2
# 11                              5.4                            9.4
# 12                              5.4                            8.4
# 13                              5.3                            8.8
# 14                              5.3                            8.7
# 15                              5.3                            8.7
# 16                              5.8                            8.1
# 17                              5.6                            8.0
# 18                              6.0                            8.1
# 19                              6.2                            7.4
# 20                              5.6                            7.8
# 21                              5.9                            7.5
# 22                              6.3                            7.9
# 23                              6.9                            8.0
# 24                              6.6                            8.5
# 25                              7.4                            8.8
# 26                              7.5                            7.8
# 27                              7.1                            7.4
# 28                              5.9                           12.2
# 29                              5.9                            8.5
# 30                              5.9                            8.3
# 31                              5.2                            8.6
#
#     Potato consumption per capita  Cucumber consumption per capita  \
# 0                            48.3                              5.0
# 1                            47.7                              5.2
# 2                            47.3                              5.4
# 3                            46.8                              5.3
# 4                            46.5                              5.5
# 5                            46.5                              5.7
# 6                            46.3                              5.8
# 7                            46.5                              6.0
# 8                            46.7                              6.2
# 9                            47.0                              6.2
# 10                           47.1                              6.4
# 11                           46.6                              6.3
# 12                           44.3                              6.6
# 13                           46.8                              6.2
# 14                           45.8                              6.4
# 15                           41.3                              6.2
# 16                           38.6                              6.1
# 17                           38.7                              6.4
# 18                           37.8                              6.4
# 19                           36.6                              6.8
# 20                           36.8                              6.7
# 21                           34.0                              6.4
# 22                           34.5                              7.1
# 23                           34.5                              7.3
# 24                           33.6                              7.4
# 25                           34.2                              7.5
# 26                           33.7                              8.1
# 27                           34.9                              7.4
# 28                           33.1                              8.0
# 29                           30.1                              7.8
# 30                           30.3                              7.5
# 31                           29.3                              8.0
#
#     US annual agriculture operation costs  \
# 0                            131554000000
# 1                            147170000000
# 2                            144800000000
# 3                            155160000000
# 4                            160670000000
# 5                            167800000000
# 6                            174950000000
# 7                            183180000000
# 8                            183150000000
# 9                            184050000000
# 10                           189600000000
# 11                           195200000000
# 12                           193100000000
# 13                           200500000000
# 14                           211800000000
# 15                           222940000000
# 16                           237810000000
# 17                           283520000000
# 18                           307020000000
# 19                           287400000000
# 20                           289050000000
# 21                           318650000000
# 22                           360100000000
# 23                           367270000000
# 24                           397600000000
# 25                           362800000000
# 26                           346900000000
# 27                           357800000000
# 28                           354000000000
# 29                           357800000000
# 30                           366200000000
# 31                           378191000000
#
#     World Population as of 1 Jan in Thousands
# 0                                 5269760.352
# 1                                 5362591.372
# 2                                 5449900.363
# 3                                 5535471.822
# 4                                 5619395.224
# 5                                 5702060.762
# 6                                 5784378.146
# 7                                 5865912.450
# 8                                 5947050.072
# 9                                 6027574.888
# 10                                6107942.028
# 11                                6189855.922
# 12                                6271638.043
# 13                                6353176.677
# 14                                6434620.053
# 15                                6516882.903
# 16                                6599469.335
# 17                                6683363.101
# 18                                6768533.988
# 19                                6854660.556
# 20                                6941951.260
# 21                                7029254.950
# 22                                7116995.900
# 23                                7206399.942
# 24                                7294786.798
# 25                                7383240.040
# 26                                7469955.033
# 27                                7556993.443
# 28                                7642651.364
# 29                                7724928.292
# 30                                7804973.773
# 31                                7876931.987
#
# [32 rows x 37 columns]

# %% [raw]
# Using results from our previous iteration for potato, cucumber and carrot, the variables herbicide and pesticide quantity are found to be most relevant. Thus we will combine it with the 3 new independent variables to find the combination that produces the best adjusted r^2. This is repeated for corn and broccoli with the relevant variables found from previous iteration

# %%
for crop in ["Potato","Cucumber","Carrot"]:
    print(f"\n\n\n------------------------------------------------{crop}----------------------------------------------\n\n\n\n")
    buildModel(improved_final_df,crop,[crop+" Herbicide",crop+" Pesticide",crop+" consumption per capita","US annual agriculture operation costs","World Population as of 1 Jan in Thousands"],crop+" Price")
    buildModel(improved_final_df,crop,[crop+" Herbicide",crop+" Pesticide",crop+" consumption per capita","US annual agriculture operation costs"],crop+" Price")
    buildModel(improved_final_df,crop,[crop+" Herbicide",crop+" Pesticide",crop+" consumption per capita","World Population as of 1 Jan in Thousands"],crop+" Price")
    buildModel(improved_final_df,crop,[crop+" Herbicide",crop+" Pesticide","US annual agriculture operation costs","World Population as of 1 Jan in Thousands"],crop+" Price")
    buildModel(improved_final_df,crop,[crop+" consumption per capita","US annual agriculture operation costs","World Population as of 1 Jan in Thousands"],crop+" Price")
# Out:
# ------------------------------------------------Potato----------------------------------------------
#
#
#
#
# final coefficients respective to order of input ['Potato Herbicide', 'Potato Pesticide', 'Potato consumption per capita', 'US annual agriculture operation costs', 'World Population as of 1 Jan in Thousands']  are:
#  [[ 7.42695442]
#  [ 0.20582201]
#  [-0.19219334]
#  [-0.90389234]
#  [ 0.44595295]
#  [ 0.0807404 ]] and final cost is: 0
# final coefficients respective to order of input ['Potato Herbicide', 'Potato Pesticide', 'Potato consumption per capita', 'US annual agriculture operation costs']  are:
#  [[ 7.42695442]
#  [ 0.21948004]
#  [-0.22599698]
#  [-0.91746011]
#  [ 0.48968675]] and final cost is: 0
# final coefficients respective to order of input ['Potato Herbicide', 'Potato Pesticide', 'Potato consumption per capita', 'World Population as of 1 Jan in Thousands']  are:
#  [[ 7.42695442]
#  [ 0.22387196]
#  [-0.21554347]
#  [-1.10981508]
#  [ 0.29039153]] and final cost is: 0
# final coefficients respective to order of input ['Potato Herbicide', 'Potato Pesticide', 'US annual agriculture operation costs', 'World Population as of 1 Jan in Thousands']  are:
#  [[ 7.42695442]
#  [ 0.4006865 ]
#  [-0.42768621]
#  [ 0.8223169 ]
#  [ 0.36367952]] and final cost is: 0
# final coefficients respective to order of input ['Potato consumption per capita', 'US annual agriculture operation costs', 'World Population as of 1 Jan in Thousands']  are:
#  [[ 7.42695442]
#  [-1.04686579]
#  [ 0.46236747]
#  [ 0.10846338]] and final cost is: 0
# ------------------------------------------------Cucumber----------------------------------------------
#
#
#
#
# final coefficients respective to order of input ['Cucumber Herbicide', 'Cucumber Pesticide', 'Cucumber consumption per capita', 'US annual agriculture operation costs', 'World Population as of 1 Jan in Thousands']  are:
#  [[22.61738489]
#  [ 0.9247653 ]
#  [ 1.74861158]
#  [-3.6862266 ]
#  [ 2.71377813]
#  [-0.65459647]] and final cost is: 3
# final coefficients respective to order of input ['Cucumber Herbicide', 'Cucumber Pesticide', 'Cucumber consumption per capita', 'US annual agriculture operation costs']  are:
#  [[22.61738489]
#  [ 0.84900976]
#  [ 1.69713737]
#  [-3.98287407]
#  [ 2.38511341]] and final cost is: 3
# final coefficients respective to order of input ['Cucumber Herbicide', 'Cucumber Pesticide', 'Cucumber consumption per capita', 'World Population as of 1 Jan in Thousands']  are:
#  [[22.61738489]
#  [ 0.92911456]
#  [ 2.00226014]
#  [-2.67569511]
#  [ 0.95718421]] and final cost is: 4
# final coefficients respective to order of input ['Cucumber Herbicide', 'Cucumber Pesticide', 'US annual agriculture operation costs', 'World Population as of 1 Jan in Thousands']  are:
#  [[22.61738489]
#  [ 1.20277418]
#  [ 2.46484735]
#  [ 1.39075307]
#  [-2.72470682]] and final cost is: 4
# final coefficients respective to order of input ['Cucumber consumption per capita', 'US annual agriculture operation costs', 'World Population as of 1 Jan in Thousands']  are:
#  [[22.61738489]
#  [-5.00288129]
#  [ 3.44239013]
#  [-0.19116426]] and final cost is: 3
# ------------------------------------------------Carrot----------------------------------------------
#
#
#
#
# final coefficients respective to order of input ['Carrot Herbicide', 'Carrot Pesticide', 'Carrot consumption per capita', 'US annual agriculture operation costs', 'World Population as of 1 Jan in Thousands']  are:
#  [[21.26086353]
#  [-0.17686659]
#  [ 1.1634141 ]
#  [-2.15250126]
#  [ 3.00203665]
#  [ 1.61071871]] and final cost is: 4
# final coefficients respective to order of input ['Carrot Herbicide', 'Carrot Pesticide', 'Carrot consumption per capita', 'US annual agriculture operation costs']  are:
#  [[21.26086353]
#  [ 0.14670397]
#  [ 0.43644492]
#  [-2.18443683]
#  [ 4.05350989]] and final cost is: 4
# final coefficients respective to order of input ['Carrot Herbicide', 'Carrot Pesticide', 'Carrot consumption per capita', 'World Population as of 1 Jan in Thousands']  are:
#  [[21.26086353]
#  [-0.37766408]
#  [ 1.34154275]
#  [-2.37822143]
#  [ 4.37967814]] and final cost is: 4
# final coefficients respective to order of input ['Carrot Herbicide', 'Carrot Pesticide', 'US annual agriculture operation costs', 'World Population as of 1 Jan in Thousands']  are:
#  [[21.26086353]
#  [-0.66263697]
#  [ 1.39056814]
#  [ 3.7872938 ]
#  [ 2.11348579]] and final cost is: 5
# final coefficients respective to order of input ['Carrot consumption per capita', 'US annual agriculture operation costs', 'World Population as of 1 Jan in Thousands']  are:
#  [[21.26086353]
#  [-2.12165799]
#  [ 2.79781325]
#  [ 0.92015241]] and final cost is: 4

# %%
for crop in ["Corn"]:
    buildModel(improved_final_df,crop,[crop+" Herbicide",crop+" Fungicide",crop+" consumption per capita","US annual agriculture operation costs","World Population as of 1 Jan in Thousands"],crop+" Price")
    buildModel(improved_final_df,crop,[crop+" Herbicide",crop+" Fungicide",crop+" consumption per capita","US annual agriculture operation costs"],crop+" Price")
    buildModel(improved_final_df,crop,[crop+" Herbicide",crop+" Fungicide",crop+" consumption per capita","World Population as of 1 Jan in Thousands"],crop+" Price")
    buildModel(improved_final_df,crop,[crop+" Herbicide",crop+" Fungicide","US annual agriculture operation costs","World Population as of 1 Jan in Thousands"],crop+" Price")
    buildModel(improved_final_df,crop,[crop+" consumption per capita","US annual agriculture operation costs","World Population as of 1 Jan in Thousands"],crop+" Price")
# Out:
# final coefficients respective to order of input ['Corn Herbicide', 'Corn Fungicide', 'Corn consumption per capita', 'US annual agriculture operation costs', 'World Population as of 1 Jan in Thousands']  are:
#  [[ 3.38173817]
#  [ 0.19791035]
#  [-0.14706449]
#  [ 0.37872447]
#  [ 1.35818158]
#  [-0.75324625]] and final cost is: 0
# final coefficients respective to order of input ['Corn Herbicide', 'Corn Fungicide', 'Corn consumption per capita', 'US annual agriculture operation costs']  are:
#  [[ 3.38173817]
#  [ 0.24507795]
#  [-0.28502266]
#  [ 0.02688494]
#  [ 1.07026102]] and final cost is: 0
# final coefficients respective to order of input ['Corn Herbicide', 'Corn Fungicide', 'Corn consumption per capita', 'World Population as of 1 Jan in Thousands']  are:
#  [[ 3.38173817]
#  [ 0.33561151]
#  [-0.2755204 ]
#  [ 1.02362249]
#  [-0.07604722]] and final cost is: 0
# final coefficients respective to order of input ['Corn Herbicide', 'Corn Fungicide', 'US annual agriculture operation costs', 'World Population as of 1 Jan in Thousands']  are:
#  [[ 3.38173817]
#  [ 0.17861376]
#  [-0.11647962]
#  [ 1.49827694]
#  [-0.53700795]] and final cost is: 0
# final coefficients respective to order of input ['Corn consumption per capita', 'US annual agriculture operation costs', 'World Population as of 1 Jan in Thousands']  are:
#  [[ 3.38173817]
#  [ 0.33630956]
#  [ 1.4356102 ]
#  [-0.81206921]] and final cost is: 0

# %%
for crop in ["Broccoli"]:
    buildModel(improved_final_df,crop,["Herbicide Price","Fungicide Price", "Pesticide Price",crop+" consumption per capita","US annual agriculture operation costs","World Population as of 1 Jan in Thousands"],crop+" Price")
    buildModel(improved_final_df,crop,["Herbicide Price","Fungicide Price", "Pesticide Price",crop+" consumption per capita","US annual agriculture operation costs"],crop+" Price")
    buildModel(improved_final_df,crop,["Herbicide Price","Fungicide Price", "Pesticide Price",crop+" consumption per capita","World Population as of 1 Jan in Thousands"],crop+" Price")
    buildModel(improved_final_df,crop,["Herbicide Price","Fungicide Price", "Pesticide Price","US annual agriculture operation costs","World Population as of 1 Jan in Thousands"],crop+" Price")
    buildModel(improved_final_df,crop,[crop+" consumption per capita","US annual agriculture operation costs","World Population as of 1 Jan in Thousands"],crop+" Price")
# Out:
# final coefficients respective to order of input ['Herbicide Price', 'Fungicide Price', 'Pesticide Price', 'Broccoli consumption per capita', 'US annual agriculture operation costs', 'World Population as of 1 Jan in Thousands']  are:
#  [[33.59346873]
#  [-0.30338112]
#  [ 2.48628538]
#  [-0.78513835]
#  [ 0.40173294]
#  [ 1.80973958]
#  [ 8.44816597]] and final cost is: 3
# final coefficients respective to order of input ['Herbicide Price', 'Fungicide Price', 'Pesticide Price', 'Broccoli consumption per capita', 'US annual agriculture operation costs']  are:
#  [[ 3.35934687e+01]
#  [-1.07301131e+00]
#  [ 2.93267321e+00]
#  [-6.86295881e-01]
#  [-1.36629955e-02]
#  [ 1.03429367e+01]] and final cost is: 8
# final coefficients respective to order of input ['Herbicide Price', 'Fungicide Price', 'Pesticide Price', 'Broccoli consumption per capita', 'World Population as of 1 Jan in Thousands']  are:
#  [[33.59346873]
#  [-0.08922049]
#  [ 2.38586324]
#  [-1.03695285]
#  [ 0.61907767]
#  [ 9.92229581]] and final cost is: 3
# final coefficients respective to order of input ['Herbicide Price', 'Fungicide Price', 'Pesticide Price', 'US annual agriculture operation costs', 'World Population as of 1 Jan in Thousands']  are:
#  [[33.59346873]
#  [-0.23446941]
#  [ 2.43651505]
#  [-0.71445408]
#  [ 2.18037994]
#  [ 8.36317184]] and final cost is: 3
# final coefficients respective to order of input ['Broccoli consumption per capita', 'US annual agriculture operation costs', 'World Population as of 1 Jan in Thousands']  are:
#  [[33.59346873]
#  [ 0.17509485]
#  [ 1.29854175]
#  [ 8.34207496]] and final cost is: 5

# %% [raw]
# #findings summary:
#
# best adjusted r^2 for each crop and the relevant combination of independent variable
#
# Broccoli-> 0.5720 -> all chemical prices,operation cost and world population, a  improvement from the previous 0.37652
# Corn ->  -1.314 , a deprovement from the previous -1.0562
# Potato-> 0.80711 herbicide quantity,pesticide quantity,and all the 3 new variables , an improvement from previous 0.743
# Cucumber->0.345 , a deprovement from previous 0.5354
# Carrot-> 0.4662 only consumption,agriculture and world population,a significant improvement from the previous -0.105708

# %% [markdown]
# ### Discussion and Analysis
#
# Discuss your model and accuracy in solving the problem. Analyze the results of your metrics. Put any conclusion here.

# %% [raw]
# Accuracy of model:
#
# 1.prediction for price of corn is very bad (negative adjusted r2) hence we decided to omit the corn from our price prediction. A reason could be that most corn in the US is used for livestock and ethanol production which we did not consider in our model
#
# 2.There is missing data in our original dataset and we are unable to cut down more (otherwise we would have less than 30 rows) and we are unable to find years earlier than 1990 for most of the data(due to lack of histrocial documentation efforts in past).Since we had to fill in missing values via plotting a linear graph using the values available which is the best way we can think of to logically guess the missing values, there is a linear trend within values guessed which is definitely not the most accurate and reflective of what real world values are. Therefore, despite some of the high adjusted r^2 values, it might not necessarily mean our model is truly more accurate.
#
# Metric analysis:
# As seen from comparison of adjusted r^2, prices of some crops are more dependent on quantities of chemicals(e.g cucumber) while others are more dependent on conumption or operating costs(e.g carrot,potato), the rest are dependent on a mixture of both(e.g  broccoli) .This could be due to certain crops being more suceptible to pests or weeds while other crops are more hardy thus the crop yield and thus supply and price are affected by the amount of chemicals used or the prices of these chemicals
#
# Conclusion:
#
# Finally, to construct the equation for the price of each crop, we look at the combinations of independent variables that produce the best adjusted r^2 and take the coefficients printed under the relevant visualisation
#
# Price of Broccoli (USD/tonne)
# ->best adjusted r^2: 0.5720
# ->variables:herbicide,pesticide and fungicide prices,US annual agriculture operation costs and World Population as of 1 Jan in Thousands
# ->final eqn:
# 33.59-0.23*Herbicide Price+2.44*Fungicide Price-0.71*Pesticide Price+2.18*US annual agriculture operation costs+8.36*WorldPopulation as of 1 Jan in Thousands
#
#
# Price of Potato (USD/tonne)
# ->best adjusted r^2: 0.80711
# -> variables:Potato consumption per capita,US annual agriculture operation costs,World Population as of 1 Jan in Thousands
# ->final eqn:
# 7.42-1.05*Potato consumption per capita+0.46*US annual agriculture operation costs+0.11*World Population as of 1 Jan in Thousands
#
# Price of Cucumber (USD/tonne)
# ->best adjusted r^2:0.5354
# ->variables:  herbicide and pesticide quantity
# -> final eqn: 22.62+0.50*Herbicide quatity used on cucumber+2.43*Pesticide quantity used on cucumber
#
# Price of Carrot (USD/tonne)
# ->best adjusted r^2: 0.4662
# ->variables: consumption,agriculture and world population
# -> final eqn:
# 21.26-2.12*Carrot consumption per capita+2.80*US annual agriculture operation costs+0.92*World Population as of 1 Jan in Thousands
#
# Our final product will be an equation that can predict total costs of Carrot,Cucumber,Potato and Broccoli based on the following user inputs:
# herbicide prices(USD/gallon)
# pesticide prices (USD/gallon)
# fungicide prices (USD/gallon)
# US annual agriculture operation costs (USD)
# world population as of 1 Jan(thousands)
# Potato consumption per capita (lb)
# Carrot consumption per capita (lb)
# Herbicide quantity used on all cucumber crops across whole of US (lb)
# Pesticide quantity used on all cucumber crops across whole of US (lb)
# amount of each of the crops consumed for the year(tonnes)
#
# ouput : total costs of Carrot,Cucumber,Potato and Broccoli(USD)

# %%
# final function that will handle user input and give total cost

def calcTotalCost(herbicide_prices,pesticide_prices,fungicide_prices,US_annual_agriculture_operation_costs,world_population,
Potato_consumption_per_capita,Carrot_consumption_per_capita,Cucumber_Herbicide_quantity,Cucumber_Pesticide_quantity,total_consumption_potato,total_consumption_carrot,total_consumption_broccoli,
total_consumption_cucumber):
    carrot_price=21.26-2.12*Carrot_consumption_per_capita+2.80*US_annual_agriculture_operation_costs+0.92*world_population
    cucumber_price=22.62+0.50*Cucumber_Herbicide_quantityr+2.43*Cucumber_Pesticide_quantity
    potato_price=7.42-1.05*Potato_consumption_per_capita+0.46*US_annual_agriculture_operation_costs+0.11*world_population
    broccoli_price=33.59-0.23*herbicide_prices+2.44*fungicide_prices-0.71*pesticide_prices+2.18*US_annual_agriculture_operation_costs+8.36*world_population
    return carrot_price*total_consumption_carrot+cucumber_price*total_consumption_cucumber+potato_price*total_consumption_potato+broccoli_price*total_consumption_broccoli
